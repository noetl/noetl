# %% [markdown]
# # NoETL Execution Validation Notebook
#
# Validate a playbook execution by inspecting server APIs, database tables, and local logs.
#
# - Uses HTTP API to fetch execution summary and events
# - Queries Postgres "noetl.error_log" for recent errors
# - Reads final table "weather_alert_summary" for inserted rows
# - Optionally inspects local JSON logs in `logs/`

# %%
# Configuration
import os, json, time, pathlib

# Server
HOST = os.environ.get('NOETL_HOST', 'localhost')
PORT = int(os.environ.get('NOETL_PORT', '8082'))
BASE = f'http://{HOST}:{PORT}/api'

# Database (defaults align with .env)
PGHOST = os.environ.get('POSTGRES_HOST', os.environ.get('PGHOST', 'localhost'))
PGPORT = int(os.environ.get('POSTGRES_PORT', os.environ.get('PGPORT', '30543')))
PGUSER = os.environ.get('POSTGRES_USER', os.environ.get('PGUSER', 'demo'))
PGPASSWORD = os.environ.get('POSTGRES_PASSWORD', os.environ.get('PGPASSWORD', 'demo'))
PGDATABASE = os.environ.get('POSTGRES_DB', os.environ.get('PGDATABASE', 'demo_noetl'))

# If you already know the execution id, set it here (as string or int)
EXECUTION_ID = os.environ.get('NOETL_LAST_EXECUTION_ID') or ''

# Resolve logs directory robustly when running from notebooks/
LOGS_DIR_ENV = os.environ.get('NOETL_LOG_DIR')
LOGS_DIR_CANDIDATES = []
if LOGS_DIR_ENV: LOGS_DIR_CANDIDATES.append(pathlib.Path(LOGS_DIR_ENV))
LOGS_DIR_CANDIDATES += [pathlib.Path('logs'), pathlib.Path('../logs'), pathlib.Path('../../logs')]
LOGS_DIR = next((p for p in LOGS_DIR_CANDIDATES if p.exists()), pathlib.Path('logs'))

print('Server:', BASE)
print('DB:', PGHOST, PGPORT, PGUSER, PGDATABASE)
print('Logs dir:', str(LOGS_DIR), 'exists:', LOGS_DIR.exists())
# Out:
# Server: http://localhost:8082/api
# DB: localhost 30543 demo demo_noetl
# Logs dir: ../logs exists: True

# %%
# Helper HTTP GET with stdlib fallback
def http_get_json(url: str):
    try:
        import requests  # type: ignore
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        return r.json()
    except Exception:
        import urllib.request, urllib.error
        try:
            with urllib.request.urlopen(url, timeout=30) as resp:
                return json.loads(resp.read().decode('utf-8'))
        except Exception as e:
            print('HTTP error:', e)
            return None

def pretty(obj):
    print(json.dumps(obj, indent=2, ensure_ascii=False))

# %%
# Try to infer EXECUTION_ID if not provided
if not EXECUTION_ID:
    # 1) Try status.json in repo root
    st = pathlib.Path('status.json')
    if st.exists():
        try:
            data = json.loads(st.read_text(encoding='utf-8'))
            eid = data.get('id') or data.get('execution_id')
            if eid:
                EXECUTION_ID = str(eid)
        except Exception:
            pass

# 2) Try server /executions to pick the most recent
if not EXECUTION_ID:
    ex_list = http_get_json(f'{BASE}/executions')
    if isinstance(ex_list, list) and ex_list:
        # Items are dicts; keep first
        eid = ex_list[0].get('execution_id') or ex_list[0].get('id')
        if eid:
            EXECUTION_ID = str(eid)

print('EXECUTION_ID =', EXECUTION_ID or '(set me)')
# Out:
# EXECUTION_ID = 222437731135913984

# %%
# Fetch execution summary
if EXECUTION_ID:
    summary = http_get_json(f'{BASE}/executions/{EXECUTION_ID}')
    print('Execution summary:')
    pretty(summary)
else:
    print('Please set EXECUTION_ID above.')
# Out:
# Execution summary:
# {
#   "id": "222437731135913984",
#   "playbook_id": "",
#   "playbook_name": "Unknown",
#   "status": "completed",
#   "start_time": "2025-09-05T14:28:07.806437",
#   "end_time": "2025-09-05T14:28:10.777129",
#   "duration": 2.970692,
#   "progress": 100,
#   "result": {},
#   "error": null,
#   "events": [
#     {
#       "event_id": "222437731148496897",
#       "event_type": "execution_start",
#       "node_id": "222437731148496897",
#       "node_name": "city_process",
#       "node_type": "playbook",
#       "status": "in_progress",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:07.806437",
#       "input_context": {
#         "path": "examples/weather/city_process",
#         "version": "0.1.0",
#         "workload": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "base_url": "",
#           "temperature_threshold": ""
#         }
#       },
#       "output_result": {},
#       "metadata": {
#         "playbook_path": "examples/weather/city_process",
#         "resource_path": "examples/weather/city_process",
#         "resource_version": "0.1.0",
#         "parent_execution_id": "222437726840946688",
#         "parent_step": "city_loop"
#       },
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": "examples/weather/city_process",
#       "resource_version": "0.1.0",
#       "normalized_status": "running"
#     },
#     {
#       "event_id": "222437731387572224",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-1",
#       "node_name": "start",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:07.855725",
#       "input_context": {
#         "workload": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "base_url": "",
#           "temperature_threshold": ""
#         }
#       },
#       "output_result": {
#         "skipped": true,
#         "reason": "control_step"
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437732272570368",
#       "event_type": "action_started",
#       "node_id": "222437731135913984-step-2",
#       "node_name": "debug_city_format",
#       "node_type": "task",
#       "status": "RUNNING",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:08.067092",
#       "input_context": {
#         "work": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "_meta": {
#             "parent_step": "city_loop",
#             "parent_execution_id": "222437726840946688"
#           },
#           "base_url": "",
#           "temperature_threshold": ""
#         },
#         "task": {
#           "name": "debug_city_format",
#           "type": "python",
#           "with": {
#             "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#             "base_url": ""
#           },
#           "code_b64": "..."
#         }
#       },
#       "output_result": {},
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "running"
#     },
#     {
#       "event_id": "222437732390010880",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-2",
#       "node_name": "debug_city_format",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:08.096908",
#       "input_context": {},
#       "output_result": {
#         "id": "759204d3-1faa-4df4-964d-bbc318259b86",
#         "status": "success",
#         "data": {
#           "lat": 48.85,
#           "lon": 2.35,
#           "name": "Paris",
#           "original": {
#             "lat": 48.85,
#             "lon": 2.35,
#             "name": "Paris"
#           }
#         }
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437736869527552",
#       "event_type": "action_started",
#       "node_id": "222437731135913984-step-3",
#       "node_name": "get_forecast",
#       "node_type": "task",
#       "status": "RUNNING",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:09.163273",
#       "input_context": {
#         "work": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "_meta": {
#             "parent_step": "city_loop",
#             "parent_execution_id": "222437726840946688"
#           },
#           "base_url": "",
#           "temperature_threshold": ""
#         },
#         "task": {
#           "name": "get_forecast",
#           "type": "http",
#           "method": "GET",
#           "endpoint": "https://api.open-meteo.com/v1/forecast",
#           "with": {
#             "debug_data": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris', 'original': {'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}}",
#             "base_url": ""
#           },
#           "params": {
#             "latitude": "48.85",
#             "longitude": "2.35",
#             "hourly": "temperature_2m",
#             "forecast_days": 1
#           },
#           "timeout": 10
#         }
#       },
#       "output_result": {},
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "running"
#     },
#     {
#       "event_id": "222437739918786560",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-3",
#       "node_name": "get_forecast",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:09.890195",
#       "input_context": {},
#       "output_result": {
#         "id": "69257ce9-11a8-40a8-bc7d-5806cd8af759",
#         "status": "success",
#         "data": {
#           "status_code": 200,
#           "headers": {
#             "date": "Fri, 05 Sep 2025 19:28:09 GMT",
#             "content-type": "application/json; charset=utf-8",
#             "transfer-encoding": "chunked",
#             "connection": "keep-alive",
#             "content-encoding": "deflate"
#           },
#           "url": "https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&hourly=temperature_2m&forecast_days=1",
#           "elapsed": 0.671849,
#           "data": {
#             "latitude": 48.84,
#             "longitude": 2.3599997,
#             "generationtime_ms": 0.05161762237548828,
#             "utc_offset_seconds": 0,
#             "timezone": "GMT",
#             "timezone_abbreviation": "GMT",
#             "elevation": 46.0,
#             "hourly_units": {
#               "time": "iso8601",
#               "temperature_2m": "°C"
#             },
#             "hourly": {
#               "time": [
#                 "2025-09-05T00:00",
#                 "2025-09-05T01:00",
#                 "2025-09-05T02:00",
#                 "2025-09-05T03:00",
#                 "2025-09-05T04:00",
#                 "2025-09-05T05:00",
#                 "2025-09-05T06:00",
#                 "2025-09-05T07:00",
#                 "2025-09-05T08:00",
#                 "2025-09-05T09:00",
#                 "2025-09-05T10:00",
#                 "2025-09-05T11:00",
#                 "2025-09-05T12:00",
#                 "2025-09-05T13:00",
#                 "2025-09-05T14:00",
#                 "2025-09-05T15:00",
#                 "2025-09-05T16:00",
#                 "2025-09-05T17:00",
#                 "2025-09-05T18:00",
#                 "2025-09-05T19:00",
#                 "2025-09-05T20:00",
#                 "2025-09-05T21:00",
#                 "2025-09-05T22:00",
#                 "2025-09-05T23:00"
#               ],
#               "temperature_2m": [
#                 16.1,
#                 15.5,
#                 15.1,
#                 14.7,
#                 14.2,
#                 13.7,
#                 13.4,
#                 14.0,
#                 15.3,
#                 17.0,
#                 18.4,
#                 19.5,
#                 20.9,
#                 21.3,
#                 21.7,
#                 21.7,
#                 21.6,
#                 21.4,
#                 21.3,
#                 20.7,
#                 19.7,
#                 18.8,
#                 17.6,
#                 16.9
#               ]
#             }
#           }
#         }
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437741231603712",
#       "event_type": "action_started",
#       "node_id": "222437731135913984-step-4",
#       "node_name": "evaluate_weather",
#       "node_type": "task",
#       "status": "RUNNING",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.204150",
#       "input_context": {
#         "work": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "_meta": {
#             "parent_step": "city_loop",
#             "parent_execution_id": "222437726840946688"
#           },
#           "base_url": "",
#           "temperature_threshold": ""
#         },
#         "task": {
#           "name": "evaluate_weather",
#           "type": "python",
#           "with": {
#             "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#             "threshold": "",
#             "forecast_data": "{'status_code': 200, 'headers': {'date': 'Fri, 05 Sep 2025 19:28:09 GMT', 'content-type': 'application/json; charset=utf-8', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'content-encoding': 'deflate'}, 'url': 'https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&hourly=temperature_2m&forecast_days=1', 'elapsed': 0.671849, 'data': {'latitude': 48.84, 'longitude': 2.3599997, 'generationtime_ms': 0.05161762237548828, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 46.0, 'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C'}, 'hourly': {'time': ['2025-09-05T00:00', '2025-09-05T01:00', '2025-09-05T02:00', '2025-09-05T03:00', '2025-09-05T04:00', '2025-09-05T05:00', '2025-09-05T06:00', '2025-09-05T07:00', '2025-09-05T08:00', '2025-09-05T09:00', '2025-09-05T10:00', '2025-09-05T11:00', '2025-09-05T12:00', '2025-09-05T13:00', '2025-09-05T14:00', '2025-09-05T15:00', '2025-09-05T16:00', '2025-09-05T17:00', '2025-09-05T18:00', '2025-09-05T19:00', '2025-09-05T20:00', '2025-09-05T21:00', '2025-09-05T22:00', '2025-09-05T23:00'], 'temperature_2m': [16.1, 15.5, 15.1, 14.7, 14.2, 13.7, 13.4, 14.0, 15.3, 17.0, 18.4, 19.5, 20.9, 21.3, 21.7, 21.7, 21.6, 21.4, 21.3, 20.7, 19.7, 18.8, 17.6, 16.9]}}}"
#           },
#           "code_b64": "..."
#         }
#       },
#       "output_result": {},
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "running"
#     },
#     {
#       "event_id": "222437741361627136",
#       "event_type": "action_started",
#       "node_id": "222437731135913984-step-4",
#       "node_name": "evaluate_weather",
#       "node_type": "task",
#       "status": "RUNNING",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.235032",
#       "input_context": {
#         "work": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "_meta": {
#             "parent_step": "city_loop",
#             "parent_execution_id": "222437726840946688"
#           },
#           "base_url": "",
#           "temperature_threshold": ""
#         },
#         "task": {
#           "name": "evaluate_weather",
#           "type": "python",
#           "with": {
#             "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#             "threshold": "",
#             "forecast_data": "{'status_code': 200, 'headers': {'date': 'Fri, 05 Sep 2025 19:28:09 GMT', 'content-type': 'application/json; charset=utf-8', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'content-encoding': 'deflate'}, 'url': 'https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&hourly=temperature_2m&forecast_days=1', 'elapsed': 0.671849, 'data': {'latitude': 48.84, 'longitude': 2.3599997, 'generationtime_ms': 0.05161762237548828, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 46.0, 'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C'}, 'hourly': {'time': ['2025-09-05T00:00', '2025-09-05T01:00', '2025-09-05T02:00', '2025-09-05T03:00', '2025-09-05T04:00', '2025-09-05T05:00', '2025-09-05T06:00', '2025-09-05T07:00', '2025-09-05T08:00', '2025-09-05T09:00', '2025-09-05T10:00', '2025-09-05T11:00', '2025-09-05T12:00', '2025-09-05T13:00', '2025-09-05T14:00', '2025-09-05T15:00', '2025-09-05T16:00', '2025-09-05T17:00', '2025-09-05T18:00', '2025-09-05T19:00', '2025-09-05T20:00', '2025-09-05T21:00', '2025-09-05T22:00', '2025-09-05T23:00'], 'temperature_2m': [16.1, 15.5, 15.1, 14.7, 14.2, 13.7, 13.4, 14.0, 15.3, 17.0, 18.4, 19.5, 20.9, 21.3, 21.7, 21.7, 21.6, 21.4, 21.3, 20.7, 19.7, 18.8, 17.6, 16.9]}}}"
#           },
#           "code_b64": "..."
#         }
#       },
#       "output_result": {},
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "running"
#     },
#     {
#       "event_id": "222437741403570176",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-4",
#       "node_name": "evaluate_weather",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.244789",
#       "input_context": {},
#       "output_result": {
#         "id": "c879d14f-50e0-44f5-aabc-b04a4f6cc6c9",
#         "status": "success",
#         "data": {
#           "city": "Paris",
#           "max_temp": 21.7,
#           "alert": true
#         }
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437741504233473",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-4",
#       "node_name": "evaluate_weather",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.274040",
#       "input_context": {},
#       "output_result": {
#         "id": "c3a8a388-992e-419d-b611-8e9bc929cdec",
#         "status": "success",
#         "data": {
#           "city": "Paris",
#           "max_temp": 21.7,
#           "alert": true
#         }
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437742645084160",
#       "event_type": "action_started",
#       "node_id": "222437731135913984-step-6",
#       "node_name": "alert_step",
#       "node_type": "task",
#       "status": "RUNNING",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.540106",
#       "input_context": {
#         "work": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "_meta": {
#             "parent_step": "city_loop",
#             "parent_execution_id": "222437726840946688"
#           },
#           "base_url": "",
#           "temperature_threshold": ""
#         },
#         "task": {
#           "type": "python",
#           "name": "alert_step",
#           "code_b64": "ZGVmIG1haW4oKiprd2FyZ3MpOgogICAgcmV0dXJuIHt9",
#           "with": {}
#         }
#       },
#       "output_result": {},
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "running"
#     },
#     {
#       "event_id": "222437742699610112",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-6",
#       "node_name": "alert_step",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.553019",
#       "input_context": {},
#       "output_result": {
#         "id": "4ac80807-2377-49b2-ba6d-6a56bffb56ee",
#         "status": "success",
#         "data": {}
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437743349727232",
#       "event_type": "action_started",
#       "node_id": "222437731135913984-step-7",
#       "node_name": "log_step",
#       "node_type": "task",
#       "status": "RUNNING",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.707946",
#       "input_context": {
#         "work": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "_meta": {
#             "parent_step": "city_loop",
#             "parent_execution_id": "222437726840946688"
#           },
#           "base_url": "",
#           "temperature_threshold": ""
#         },
#         "task": {
#           "type": "python",
#           "name": "log_step",
#           "code_b64": "ZGVmIG1haW4oKiprd2FyZ3MpOgogICAgcmV0dXJuIHt9",
#           "with": {}
#         }
#       },
#       "output_result": {},
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "running"
#     },
#     {
#       "event_id": "222437743416836096",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-7",
#       "node_name": "log_step",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.724445",
#       "input_context": {},
#       "output_result": {
#         "id": "003fb585-358c-43a7-87c0-09d86262b719",
#         "status": "success",
#         "data": {}
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437743504916480",
#       "event_type": "action_completed",
#       "node_id": "222437731135913984-step-8",
#       "node_name": "end",
#       "node_type": "task",
#       "status": "COMPLETED",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.744885",
#       "input_context": {
#         "workload": {
#           "city": "{'lat': 48.85, 'lon': 2.35, 'name': 'Paris'}",
#           "base_url": "",
#           "temperature_threshold": ""
#         }
#       },
#       "output_result": {
#         "skipped": true,
#         "reason": "control_step"
#       },
#       "metadata": {},
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437743639134208",
#       "event_type": "execution_complete",
#       "node_id": "222437743639134208",
#       "node_name": "examples/weather/city_process",
#       "node_type": "playbook",
#       "status": "completed",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.776809",
#       "input_context": {
#         "execution_id": "222437731135913984"
#       },
#       "output_result": {},
#       "metadata": {
#         "parent_execution_id": "222437726840946688"
#       },
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     },
#     {
#       "event_id": "222437743639134209",
#       "event_type": "execution_complete",
#       "node_id": "222437743639134209",
#       "node_name": "examples/weather/city_process",
#       "node_type": "playbook",
#       "status": "completed",
#       "duration": 0.0,
#       "timestamp": "2025-09-05T14:28:10.777129",
#       "input_context": {
#         "execution_id": "222437731135913984"
#       },
#       "output_result": {},
#       "metadata": {
#         "parent_execution_id": "222437726840946688"
#       },
#       "error": null,
#       "execution_id": "222437731135913984",
#       "resource_path": null,
#       "resource_version": null,
#       "normalized_status": "completed"
#     }
#   ]
# }

# %%
# Fetch all events for the execution
events = None
if EXECUTION_ID:
    events = http_get_json(f'{BASE}/events/by-execution/{EXECUTION_ID}')
    print('Event count:', len(events.get('events', [])) if isinstance(events, dict) else 'n/a')
    # Show last 10 event summaries
    if events and isinstance(events, dict):
        for e in (events.get('events') or [])[-10:]:
            print(e.get('timestamp'), e.get('node_name'), e.get('event_type'), e.get('status'))
else:
    print('No events (or EXECUTION_ID not set).')
# Out:
# Event count: 17
# 2025-09-05T14:28:10.235032 evaluate_weather action_started RUNNING
# 2025-09-05T14:28:10.244789 evaluate_weather action_completed COMPLETED
# 2025-09-05T14:28:10.274040 evaluate_weather action_completed COMPLETED
# 2025-09-05T14:28:10.540106 alert_step action_started RUNNING
# 2025-09-05T14:28:10.553019 alert_step action_completed COMPLETED
# 2025-09-05T14:28:10.707946 log_step action_started RUNNING
# 2025-09-05T14:28:10.724445 log_step action_completed COMPLETED
# 2025-09-05T14:28:10.744885 end action_completed COMPLETED
# 2025-09-05T14:28:10.776809 examples/weather/city_process execution_complete completed
# 2025-09-05T14:28:10.777129 examples/weather/city_process execution_complete completed

# %%
# Quick inline validation:
# - Count loop iterations for city_loop
# - Ensure at least one COMPLETED action exists
if events and isinstance(events, dict):
    ev = events.get('events') or []
    loop_iters = [e for e in ev if e.get('event_type') == 'loop_iteration' and e.get('node_name') == 'city_loop']
    completed = [e for e in ev if (e.get('status') or '').lower() in ('completed','success')]
    print('city_loop.iterations =', len(loop_iters))
    print('completed events =', len(completed))
else:
    print('Events not loaded.')
# Out:
# city_loop.iterations = 0
# completed events = 10

# %%
# Inspect Postgres error log (noetl.error_log)
try:
    import psycopg
    conn = psycopg.connect(dbname=PGDATABASE, user=PGUSER, password=PGPASSWORD, host=PGHOST, port=PGPORT)
    with conn.cursor() as cur:
        cur.execute(
            """
            SELECT error_id, error_type, left(error_message, 160) AS msg, to_char(timestamp,'YYYY-MM-DD HH24:MI:SS') AS ts
            FROM noetl.error_log
            ORDER BY timestamp DESC
            LIMIT 10
            """
        )
        rows = cur.fetchall()
        print('Recent errors:')
        for r in rows:
            print(r)
    conn.close()
except Exception as e:
    print('Error querying Postgres error_log:', e)
# Out:
# Recent errors:

# %%
# Inspect final table (weather_alert_summary)
try:
    import psycopg
    conn = psycopg.connect(dbname=PGDATABASE, user=PGUSER, password=PGPASSWORD, host=PGHOST, port=PGPORT)
    with conn.cursor() as cur:
        cur.execute("SELECT COUNT(*) FROM information_schema.tables WHERE table_schema='public' AND table_name='weather_alert_summary'")
        exists = (cur.fetchone() or [0])[0] == 1
        if exists:
            cur.execute("SELECT id, alert_cities, alert_count, to_char(created_at,'YYYY-MM-DD HH24:MI:SS') FROM weather_alert_summary ORDER BY id DESC LIMIT 10")
            print('weather_alert_summary (last 10):')
            for row in cur.fetchall():
                print(row)
        else:
            print('weather_alert_summary table does not exist yet.')
    conn.close()
except Exception as e:
    print('Error querying weather_alert_summary:', e)
# Out:
# weather_alert_summary (last 10):

# %%
# Optional: inspect local JSON logs if present
for name in ('event_log.json', 'queue.json', 'runtime.json'):
    p = LOGS_DIR / name
    if p.exists():
        try:
            # Read a small prefix for sanity
            text = p.read_text(encoding='utf-8')
            print(f'--- {p} (first 600 chars) ---')
            print(text[:600])
        except Exception as e:
            print(f'Failed to read {p}:', e)
    else:
        print(f'{p} not found.')
# Out:
# --- ../logs/event_log.json (first 600 chars) ---
# [
#   {
#     "execution_id": 222437726840946688,
#     "event_id": 222437726857723904,
#     "parent_event_id": null,
#     "timestamp": "2025-09-05T14:28:06.776403",
#     "event_type": "execution_start",
#     "node_id": "222437726857723904",
#     "node_name": "weather_loop_example",
#     "node_type": "playbook",
#     "status": "in_progress",
#     "duration": 0,
#     "input_context": "{\"path\": \"examples/weather/weather_loop_example\", \"version\": \"0.1.0\", \"workload\": {\"jobId\": \"{{ job.uuid }}\", \"state\": \"ready\", \"cities\": [{\"name\": \"London\", \"lat\": 51.51, \"lon\": -0.13}, {\"name\": \"
# --- ../logs/queue.json (first 600 chars) ---
# []
#
# --- ../logs/runtime.json (first 600 chars) ---
# [
#   {
#     "runtime_id": 222437594334494720,
#     "name": "server-local",
#     "component_type": "server_api",
#     "base_url": "http://localhost:8082/api",
#     "status": "ready",
#     "labels": null,
#     "capabilities": null,
#     "capacity": null,
#     "runtime": {
#       "pid": 91045,
#       "type": "server",
#       "hostname": "kadyapams-MacBook-Air.local"
#     },
#     "last_heartbeat": "2025-09-05T14:28:05.214872-05:00",
#     "created_at": "2025-09-05T14:27:35.191959-05:00",
#     "updated_at": "2025-09-05T14:28:05.214872-05:00"
#   },
#   {
#     "runtime_id": 222437605130633216,
#     "name": "worker-cpu-01",
