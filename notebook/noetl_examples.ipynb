# %% [markdown]
# # NoETL Examples
#
# This notebook demonstrates all the examples from the NoETL README.md file. It covers various ways to use NoETL, including running the agent, using the CLI, interacting with the REST API, and analyzing execution data.
#
# ## Prerequisites
#
# Before running this notebook, make sure you have:
#
# 1. Python 3.12+
# 2. Postgres database
# 3. Docker
# 4. Folders created:
#    - `data/input` - for input payload files
#    - `data/exports` - for exported execution data
#
# ## Installation
#
# If you haven't installed NoETL yet, follow these steps:

# %%
# !cd .. && make install-uv
# !cd .. && make create-venv
# !cd .. && make install
# Out:
# uv venv
# Using CPython 3.12.7 interpreter at: /Users/akuksin/.pyenv/versions/3.12.7/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# . .venv/bin/activate
# uv pip install -e .
# Resolved 194 packages in 68ms
# Prepared 1 package in 246ms
# Installed 194 packages in 360ms
#  + aiofiles==24.1.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.13
#  + aiosignal==1.3.2
#  + alembic==1.16.2
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + appnope==0.1.4
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==21.2.0
#  + arrow==1.3.0
#  + asttokens==3.0.0
#  + async-lru==2.0.5
#  + attrs==25.3.0
#  + authlib==1.6.0
#  + babel==2.17.0
#  + backoff==2.2.1
#  + beautifulsoup4==4.13.4
#  + bleach==6.2.0
#  + cachetools==5.5.2
#  + certifi==2025.6.15
#  + cffi==1.17.1
#  + charset-normalizer==3.4.2
#  + click==8.1.8
#  + comm==0.2.2
#  + connectorx==0.4.3
#  + contourpy==1.3.2
#  + cryptography==45.0.4
#  + cycler==0.12.1
#  + debugpy==1.8.14
#  + decorator==5.2.1
#  + deepdiff==8.5.0
#  + defusedxml==0.7.1
#  + distro==1.9.0
#  + duckdb==1.3.1
#  + duckdb-engine==0.17.0
#  + executing==2.2.0
#  + fastapi==0.115.13
#  + fastjsonschema==2.21.1
#  + fonttools==4.58.4
#  + fqdn==1.5.1
#  + frozenlist==1.7.0
#  + fsspec==2025.5.1
#  + gcsfs==2025.5.1
#  + google-api-core==2.25.1
#  + google-auth==2.40.3
#  + google-auth-oauthlib==1.2.2
#  + google-cloud-appengine-logging==1.6.2
#  + google-cloud-audit-log==0.3.2
#  + google-cloud-core==2.4.3
#  + google-cloud-firestore==2.21.0
#  + google-cloud-logging==3.12.1
#  + google-cloud-secret-manager==2.24.0
#  + google-cloud-storage==3.1.1
#  + google-crc32c==1.7.1
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.70.0
#  + greenlet==3.2.3
#  + grpc-google-iam-v1==0.14.2
#  + grpcio==1.73.1
#  + grpcio-status==1.73.1
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.10
#  + importlib-metadata==8.7.0
#  + ipykernel==6.29.5
#  + ipython==9.3.0
#  + ipython-genutils==0.2.0
#  + ipython-pygments-lexers==1.1.1
#  + isoduration==20.11.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + json5==0.12.0
#  + jsonpointer==3.0.0
#  + jsonschema==4.24.0
#  + jsonschema-specifications==2025.4.1
#  + jupysql==0.11.1
#  + jupysql-plugin==0.4.5
#  + jupyter-client==8.6.3
#  + jupyter-core==5.8.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.2.5
#  + jupyter-server==2.16.0
#  + jupyter-server-terminals==0.5.3
#  + jupyterlab==4.4.3
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.27.3
#  + kiwisolver==1.4.8
#  + lark==1.2.2
#  + mako==1.3.10
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + matplotlib==3.10.3
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mistune==3.1.3
#  + multidict==6.5.1
#  + nats-py==2.10.0
#  + nbclient==0.10.2
#  + nbconvert==7.16.6
#  + nbformat==5.10.4
#  + nest-asyncio==1.6.0
#  + networkx==3.5
#  + noetl==0.0.2 (from file:///Users/akuksin/projects/noetl/noetl)
#  + notebook-shim==0.2.4
#  + numpy==2.3.1
#  + oauthlib==3.3.1
#  + opentelemetry-api==1.34.1
#  + orderly-set==5.4.1
#  + outcome==1.3.0.post0
#  + overrides==7.7.0
#  + packaging==25.0
#  + pandas==2.3.0
#  + pandocfilters==1.5.1
#  + parso==0.8.4
#  + pexpect==4.9.0
#  + pillow==11.2.1
#  + platformdirs==4.3.8
#  + ploomber-core==0.2.26
#  + polars==1.31.0
#  + posthog==5.4.0
#  + prettytable==3.16.0
#  + prometheus-client==0.22.1
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.2
#  + proto-plus==1.26.1
#  + protobuf==6.31.1
#  + psutil==7.0.0
#  + psycopg==3.2.9
#  + psycopg-binary==3.2.9
#  + psycopg-pool==3.2.6
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==20.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pycryptodome==3.23.0
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pydot==4.0.1
#  + pygments==2.19.2
#  + pyparsing==3.2.3
#  + pysocks==1.7.1
#  + python-dateutil==2.9.0.post0
#  + python-json-logger==3.3.0
#  + python-multipart==0.0.20
#  + pytz==2025.2
#  + pyyaml==6.0.2
#  + pyzmq==27.0.0
#  + referencing==0.36.2
#  + requests==2.32.4
#  + requests-oauthlib==2.0.0
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rich==14.0.0
#  + rpds-py==0.25.1
#  + rsa==4.9.1
#  + selenium==4.33.0
#  + send2trash==1.8.3
#  + setuptools==80.9.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + sortedcontainers==2.4.0
#  + soupsieve==2.7
#  + sqlalchemy==2.0.41
#  + sqlglot==26.30.0
#  + sqlmodel==0.0.24
#  + sqlparse==0.5.3
#  + stack-data==0.6.3
#  + starlette==0.46.2
#  + terminado==0.18.1
#  + tinycss2==1.4.0
#  + tornado==6.5.1
#  + traitlets==5.14.3
#  + trio==0.30.0
#  + trio-websocket==0.12.2
#  + typer==0.16.0
#  + types-python-dateutil==2.9.0.20250516
#  + typing-extensions==4.13.2
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + uri-template==1.3.0
#  + urllib3==2.4.0
#  + uvicorn==0.34.3
#  + wcwidth==0.2.13
#  + webcolors==24.11.1
#  + webencodings==0.5.1
#  + websocket-client==1.8.0
#  + wsproto==1.2.0
#  + yarl==1.20.1
#  + zipp==3.23.0

# %% [markdown]
# ## 1. Running the NoETL Agent
#
# There are two ways to run the NoETL agent from the command line:
#
# ### 1.1. Using the `noetl agent` Command
#
# The simplest way to run the NoETL agent:

# %%
# !noetl agent -f ../catalog/playbooks/weather_example.yaml --debug
# Out:
# ℹ️ [INFO]  (main:run_agent:226)
#      Message: Using default PostgreSQL connection string: dbname=noetl user=noetl password=noetl host=localhost port=5434
# [INFO] 2025-06-25T23:58:37,097 (noetl.agent:__init__:97) - Modified Postgres: dbname=noetl user=noetl password=noetl host=localhost port=5434
# [INFO] 2025-06-25T23:58:37,116 (noetl.agent:init_database:127) - Initializing database tables
# [INFO] 2025-06-25T23:58:37,118 (noetl.agent:init_database:135) - Database connection is working
# [INFO] 2025-06-25T23:58:37,118 (noetl.agent:init_database:144) - Creating workload table if it doesn't exist
# [INFO] 2025-06-25T23:58:37,123 (noetl.agent:init_database:165) - Workload table exists or was created successfully
# [INFO] 2025-06-25T23:58:37,123 (noetl.agent:init_database:171) - Testing workload table with test_id: test_cc30baed-eb0c-4eb0-a976-c989e2f3e149
# [INFO] 2025-06-25T23:58:37,127 (noetl.agent:init_database:188) - Successfully tested workload table insert and select
# [INFO] 2025-06-25T23:58:37,128 (noetl.agent:init_database:197) - Cleaned up test data from workload table
# [INFO] 2025-06-25T23:58:37,128 (noetl.agent:init_database:202) - Creating event_log table if it doesn't exist
# [INFO] 2025-06-25T23:58:37,129 (noetl.agent:init_database:235) - Creating workflow table if it doesn't exist
# [INFO] 2025-06-25T23:58:37,130 (noetl.agent:init_database:249) - Creating workbook table if it doesn't exist
# [INFO] 2025-06-25T23:58:37,131 (noetl.agent:init_database:262) - Creating transition table if it doesn't exist
# [INFO] 2025-06-25T23:58:37,132 (noetl.agent:init_database:276) - Database tables initialized successfully
# [INFO] 2025-06-25T23:58:37,133 (noetl.agent:init_database:285) - Tables in database: ['test_data_table', 'resource', 'catalog', 'event_log', 'workflow', 'workbook', 'workload', 'transition', 'weather_alert_summary']
# [INFO] 2025-06-25T23:58:37,133 (noetl.agent:load_workload:374) - Loading workload data for execution aa6a4b5a-2cf6-4854-92bd-862b37ba116b
# [INFO] 2025-06-25T23:58:37,133 (noetl.agent:load_workload:377) - Checking if workload table exists
# [INFO] 2025-06-25T23:58:37,134 (noetl.agent:load_workload:389) - Workload table exists in the database
# [INFO] 2025-06-25T23:58:37,134 (noetl.agent:load_workload:392) - Checking if workload table has any rows
# [INFO] 2025-06-25T23:58:37,134 (noetl.agent:load_workload:395) - Total rows in workload table: 16
# [INFO] 2025-06-25T23:58:37,134 (noetl.agent:load_workload:398) - Querying workload data for execution_id: aa6a4b5a-2cf6-4854-92bd-862b37ba116b
# [INFO] 2025-06-25T23:58:37,135 (noetl.agent:load_workload:417) - No workload data found for execution aa6a4b5a-2cf6-4854-92bd-862b37ba116b
# [INFO] 2025-06-25T23:58:37,135 (noetl.agent:load_workload:422) - All execution_ids in workload table: ['25bb3c66-1b70-4d01-bd59-779406528dcd', '42e713db-8899-47d2-b51d-636c945069d6', '3bc0666d-fd86-4085-abde-868ce4fdf35e', 'a6cf6cec-a8bb-4dc7-881a-772ea5fee322', 'fa360edb-d6e2-48d1-988c-0a9fe85b46e1', 'a927af04-7662-42ec-89db-64be0e790ed0', '98221acf-ae4a-40ff-bc39-d60e98ac6381', 'e9ecdcaa-dd28-40f3-bc1d-cd9786a44253', '2cc0d5ea-3ab3-4f4c-85d2-de08883a060b', '6f494720-5d00-4c5d-8eb0-099115128e9f', '0fa4ac45-816c-41a1-9aa1-3b7d7159fab3', '6f712950-83b4-4ea6-bc7a-ea0159044c18', '3251ffb7-1380-48db-b77c-ebb0431c1819', '0235a657-49ed-4039-8f88-8712260ccac1', 'c9162f63-015b-496c-be00-ac5897df98a3', '5c8dcd32-e61a-47b0-88ef-9f855ec59d89']
# [INFO] 2025-06-25T23:58:37,135 (noetl.agent:__init__:108) - Workload not found in database. Using default from playbook.
# ℹ️ [INFO]  (main:run_agent:249)
#      Message: Using default workload from playbook
# [INFO] 2025-06-25T23:58:37,154 (noetl.agent:store_workload:306) - Storing workload data for execution aa6a4b5a-2cf6-4854-92bd-862b37ba116b: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "London", "lat": 51.51, "lon": -0....
# [INFO] 2025-06-25T23:58:37,155 (noetl.agent:store_workload:332) - Executing INSERT INTO workload for execution_id: aa6a4b5a-2cf6-4854-92bd-862b37ba116b
# [INFO] 2025-06-25T23:58:37,156 (noetl.agent:store_workload:340) - INSERT INTO workload completed and committed for execution_id: aa6a4b5a-2cf6-4854-92bd-862b37ba116b
# [INFO] 2025-06-25T23:58:37,156 (noetl.agent:store_workload:343) - Verifying data was stored for execution_id: aa6a4b5a-2cf6-4854-92bd-862b37ba116b
# [INFO] 2025-06-25T23:58:37,156 (noetl.agent:store_workload:351) - Successfully stored workload data for execution aa6a4b5a-2cf6-4854-92bd-862b37ba116b. Found 1 rows.
# [INFO] 2025-06-25T23:58:37,157 (noetl.agent:store_workload:359) - Retrieved workload data for execution aa6a4b5a-2cf6-4854-92bd-862b37ba116b: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "London", "lat": 51.51, "lon": -0....
# [INFO] 2025-06-25T23:58:37,157 (noetl.agent:run:1560) - Starting playbook: weather_example
# [INFO] 2025-06-25T23:58:37,158 (noetl.agent:execute_step:1147) - Executing step: start
# [DEBUG] 2025-06-25T23:58:37,158 (noetl.agent:execute_step:1148) - Executing step: step_name=start, step_with=None
# [DEBUG] 2025-06-25T23:58:37,158 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293'}
# [DEBUG] 2025-06-25T23:58:37,158 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293'}
# [DEBUG] 2025-06-25T23:58:37,161 (noetl.agent:render_template:17) - Render template: {{ workload.state == 'ready' }}
# [DEBUG] 2025-06-25T23:58:37,161 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start']
# [INFO] 2025-06-25T23:58:37,165 (noetl.agent:execute_step:1147) - Executing step: city_loop
# [DEBUG] 2025-06-25T23:58:37,165 (noetl.agent:execute_step:1148) - Executing step: step_name=city_loop, step_with={}
# [DEBUG] 2025-06-25T23:58:37,165 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293'}
# [DEBUG] 2025-06-25T23:58:37,165 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293'}
# [DEBUG] 2025-06-25T23:58:37,166 (noetl.agent:render_template:17) - Render template: {{ workload.cities }}
# [DEBUG] 2025-06-25T23:58:37,166 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start']
# [INFO] 2025-06-25T23:58:37,166 (noetl.agent:execute_loop_step:1353) - Starting loop step with 3 items
# [DEBUG] 2025-06-25T23:58:37,166 (noetl.agent:execute_loop_step:1354) - Loop step iterator=city, items=[{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}]
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:17) - Render template: {{}}
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:execute_loop_step:1414) - Loop next step: fetch_and_evaluate, next_step_with={'city': '{{ city }}', 'base_url': '{{ workload.base_url }}', 'temperature_threshold': '{{ temperature_threshold }}'}, rules={'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}}
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}}
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:17) - Render template: {{ workload.base_url }}
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}}
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,168 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}}
# [DEBUG] 2025-06-25T23:58:37,169 (noetl.agent:execute_loop_step:1417) - Loop step rendered with: {'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [INFO] 2025-06-25T23:58:37,169 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [DEBUG] 2025-06-25T23:58:37,169 (noetl.agent:execute_step:1148) - Executing step: step_name=fetch_and_evaluate, step_with={'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [DEBUG] 2025-06-25T23:58:37,169 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293'}
# [DEBUG] 2025-06-25T23:58:37,169 (noetl.agent:execute_step:1153) - Executing step: rendered_with={'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [DEBUG] 2025-06-25T23:58:37,171 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}}
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:37,172 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:37,174 (noetl.agent:render_template:20) - Render template city value: {'name': 'London', 'lat': 51.51, 'lon': -0.13}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:37,333 (httpcore.connection:trace:47) - connect_tcp.started host='api.open-meteo.com' port=443 local_address=None timeout=5.0 socket_options=None
# [DEBUG] 2025-06-25T23:58:37,518 (httpcore.connection:trace:47) - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1093e34d0>
# [DEBUG] 2025-06-25T23:58:37,518 (httpcore.connection:trace:47) - start_tls.started ssl_context=<ssl.SSLContext object at 0x109594ed0> server_hostname='api.open-meteo.com' timeout=5.0
# [DEBUG] 2025-06-25T23:58:37,859 (httpcore.connection:trace:47) - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1093e31d0>
# [DEBUG] 2025-06-25T23:58:37,859 (httpcore.http11:trace:47) - send_request_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:37,860 (httpcore.http11:trace:47) - send_request_headers.complete
# [DEBUG] 2025-06-25T23:58:37,860 (httpcore.http11:trace:47) - send_request_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:37,860 (httpcore.http11:trace:47) - send_request_body.complete
# [DEBUG] 2025-06-25T23:58:37,860 (httpcore.http11:trace:47) - receive_response_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:38,026 (httpcore.http11:trace:47) - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 26 Jun 2025 06:58:37 GMT'), (b'Content-Type', b'application/json; charset=utf-8'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'deflate')])
# [INFO] 2025-06-25T23:58:38,026 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=51.51&longitude=-0.13&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [DEBUG] 2025-06-25T23:58:38,026 (httpcore.http11:trace:47) - receive_response_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:38,026 (httpcore.http11:trace:47) - receive_response_body.complete
# [DEBUG] 2025-06-25T23:58:38,026 (httpcore.http11:trace:47) - response_closed.started
# [DEBUG] 2025-06-25T23:58:38,026 (httpcore.http11:trace:47) - response_closed.complete
# [DEBUG] 2025-06-25T23:58:38,027 (httpcore.connection:trace:47) - close.started
# [DEBUG] 2025-06-25T23:58:38,027 (httpcore.connection:trace:47) - close.complete
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:17) - Render template: {{}}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:execute_loop_step:1414) - Loop next step: fetch_and_evaluate, next_step_with={'city': '{{ city }}', 'base_url': '{{ workload.base_url }}', 'temperature_threshold': '{{ temperature_threshold }}'}, rules={'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:17) - Render template: {{ workload.base_url }}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:execute_loop_step:1417) - Loop step rendered with: {'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [INFO] 2025-06-25T23:58:38,044 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:execute_step:1148) - Executing step: step_name=fetch_and_evaluate, step_with={'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'London', 'lat': 51.51, 'lon': -0.13}, 'fetch_and_evaluate': {'city': 'London', 'max_temp': 25.1, 'alert': False}, 'fetch_and_evaluate.result': {'city': 'London', 'max_temp': 25.1, 'alert': False}, 'fetch_and_evaluate.status': 'success', 'result': {'city': 'London', 'max_temp': 25.1, 'alert': False}}
# [DEBUG] 2025-06-25T23:58:38,044 (noetl.agent:execute_step:1153) - Executing step: rendered_with={'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [DEBUG] 2025-06-25T23:58:38,049 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, 'fetch_and_evaluate': {'city': 'London', 'max_temp': 25.1, 'alert': False}, 'fetch_and_evaluate.result': {'city': 'London', 'max_temp': 25.1, 'alert': False}, 'fetch_and_evaluate.status': 'success', 'result': {'city': 'London', 'max_temp': 25.1, 'alert': False}}
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,050 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,051 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,051 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,051 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,051 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:38,051 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,051 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,052 (noetl.agent:render_template:20) - Render template city value: {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,060 (httpcore.connection:trace:47) - connect_tcp.started host='api.open-meteo.com' port=443 local_address=None timeout=5.0 socket_options=None
# [DEBUG] 2025-06-25T23:58:38,224 (httpcore.connection:trace:47) - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x10953e990>
# [DEBUG] 2025-06-25T23:58:38,224 (httpcore.connection:trace:47) - start_tls.started ssl_context=<ssl.SSLContext object at 0x10936e0d0> server_hostname='api.open-meteo.com' timeout=5.0
# [DEBUG] 2025-06-25T23:58:38,560 (httpcore.connection:trace:47) - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x10953e840>
# [DEBUG] 2025-06-25T23:58:38,560 (httpcore.http11:trace:47) - send_request_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:38,561 (httpcore.http11:trace:47) - send_request_headers.complete
# [DEBUG] 2025-06-25T23:58:38,561 (httpcore.http11:trace:47) - send_request_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:38,561 (httpcore.http11:trace:47) - send_request_body.complete
# [DEBUG] 2025-06-25T23:58:38,561 (httpcore.http11:trace:47) - receive_response_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:38,722 (httpcore.http11:trace:47) - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 26 Jun 2025 06:58:38 GMT'), (b'Content-Type', b'application/json; charset=utf-8'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'deflate')])
# [INFO] 2025-06-25T23:58:38,722 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [DEBUG] 2025-06-25T23:58:38,723 (httpcore.http11:trace:47) - receive_response_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:38,723 (httpcore.http11:trace:47) - receive_response_body.complete
# [DEBUG] 2025-06-25T23:58:38,723 (httpcore.http11:trace:47) - response_closed.started
# [DEBUG] 2025-06-25T23:58:38,723 (httpcore.http11:trace:47) - response_closed.complete
# [DEBUG] 2025-06-25T23:58:38,723 (httpcore.connection:trace:47) - close.started
# [DEBUG] 2025-06-25T23:58:38,723 (httpcore.connection:trace:47) - close.complete
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:17) - Render template: {{}}
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:execute_loop_step:1414) - Loop next step: fetch_and_evaluate, next_step_with={'city': '{{ city }}', 'base_url': '{{ workload.base_url }}', 'temperature_threshold': '{{ temperature_threshold }}'}, rules={'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}}
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}}
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:17) - Render template: {{ workload.base_url }}
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,739 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}}
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}}
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:execute_loop_step:1417) - Loop step rendered with: {'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [INFO] 2025-06-25T23:58:38,740 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:execute_step:1148) - Executing step: step_name=fetch_and_evaluate, step_with={'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, 'fetch_and_evaluate': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, 'fetch_and_evaluate.result': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, 'fetch_and_evaluate.status': 'success', 'result': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}}
# [DEBUG] 2025-06-25T23:58:38,740 (noetl.agent:execute_step:1153) - Executing step: rendered_with={'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}
# [DEBUG] 2025-06-25T23:58:38,745 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, 'fetch_and_evaluate': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, 'fetch_and_evaluate.result': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, 'fetch_and_evaluate.status': 'success', 'result': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}}
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result']
# [DEBUG] 2025-06-25T23:58:38,746 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:38,747 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'threshold']
# [DEBUG] 2025-06-25T23:58:38,748 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:38,753 (httpcore.connection:trace:47) - connect_tcp.started host='api.open-meteo.com' port=443 local_address=None timeout=5.0 socket_options=None
# [DEBUG] 2025-06-25T23:58:38,923 (httpcore.connection:trace:47) - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1093631d0>
# [DEBUG] 2025-06-25T23:58:38,923 (httpcore.connection:trace:47) - start_tls.started ssl_context=<ssl.SSLContext object at 0x10936e450> server_hostname='api.open-meteo.com' timeout=5.0
# [DEBUG] 2025-06-25T23:58:39,262 (httpcore.connection:trace:47) - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x109362570>
# [DEBUG] 2025-06-25T23:58:39,262 (httpcore.http11:trace:47) - send_request_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:39,263 (httpcore.http11:trace:47) - send_request_headers.complete
# [DEBUG] 2025-06-25T23:58:39,263 (httpcore.http11:trace:47) - send_request_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:39,263 (httpcore.http11:trace:47) - send_request_body.complete
# [DEBUG] 2025-06-25T23:58:39,263 (httpcore.http11:trace:47) - receive_response_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:39,429 (httpcore.http11:trace:47) - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 26 Jun 2025 06:58:39 GMT'), (b'Content-Type', b'application/json; charset=utf-8'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'deflate')])
# [INFO] 2025-06-25T23:58:39,429 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [DEBUG] 2025-06-25T23:58:39,429 (httpcore.http11:trace:47) - receive_response_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:39,429 (httpcore.http11:trace:47) - receive_response_body.complete
# [DEBUG] 2025-06-25T23:58:39,429 (httpcore.http11:trace:47) - response_closed.started
# [DEBUG] 2025-06-25T23:58:39,429 (httpcore.http11:trace:47) - response_closed.complete
# [DEBUG] 2025-06-25T23:58:39,429 (httpcore.connection:trace:47) - close.started
# [DEBUG] 2025-06-25T23:58:39,429 (httpcore.connection:trace:47) - close.complete
# [INFO] 2025-06-25T23:58:39,447 (noetl.agent:execute_loop_step:1455) - Found end_loop step for city_loop: end_city_loop
# [INFO] 2025-06-25T23:58:39,448 (noetl.agent:run:1646) - Using next_step from step result: end_city_loop
# [INFO] 2025-06-25T23:58:39,452 (noetl.agent:execute_step:1147) - Executing step: end_city_loop
# [DEBUG] 2025-06-25T23:58:39,452 (noetl.agent:execute_step:1148) - Executing step: step_name=end_city_loop, step_with={}
# ...
# [DEBUG] 2025-06-25T23:58:39,485 (noetl.agent:render_template:17) - Render template: {{ aggregate_alerts.summary }}
# [DEBUG] 2025-06-25T23:58:39,485 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status']
# [DEBUG] 2025-06-25T23:58:39,485 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:39,485 (noetl.agent:execute_step:1153) - Executing step: rendered_with={'summary': {'alert_cities': ['Berlin'], 'count': 1}}
# [DEBUG] 2025-06-25T23:58:39,486 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, 'fetch_and_evaluate': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, 'fetch_and_evaluate.result': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, 'fetch_and_evaluate.status': 'success', 'result': {'global_alert': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'city_loop_results': [{'fetch_and_evaluate': {'city': 'London', 'max_temp': 25.1, 'alert': False}}, {'fetch_and_evaluate': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}}, {'fetch_and_evaluate': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}}], 'alerts': "[{'city': 'London', 'max_temp': 25.1, 'alert': False}, {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}]", 'aggregate_alerts': {'global_alert': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'aggregate_alerts.result': {'global_alert': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'aggregate_alerts.status': 'success', 'summary': {'alert_cities': ['Berlin'], 'count': 1}}
# [DEBUG] 2025-06-25T23:58:39,487 (noetl.agent:render_template:17) - Render template: {{ aggregate_alerts.summary }}
# [DEBUG] 2025-06-25T23:58:39,487 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status', 'summary']
# [DEBUG] 2025-06-25T23:58:39,487 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:39,488 (noetl.agent:render_template:17) - Render template: {{ summary }}
# [DEBUG] 2025-06-25T23:58:39,488 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status', 'summary']
# [DEBUG] 2025-06-25T23:58:39,488 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:39,488 (noetl.agent:render_template:17) - Render template: {{ summary }}
# [DEBUG] 2025-06-25T23:58:39,488 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status', 'summary']
# [DEBUG] 2025-06-25T23:58:39,488 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# Aggregated weather alert summary: {'alert_cities': ['Berlin'], 'count': 1}
# [INFO] 2025-06-25T23:58:39,498 (noetl.agent:execute_step:1147) - Executing step: store_aggregate_result
# [DEBUG] 2025-06-25T23:58:39,498 (noetl.agent:execute_step:1148) - Executing step: step_name=store_aggregate_result, step_with={'summary': '{{ aggregate_alerts.summary }}'}
# [DEBUG] 2025-06-25T23:58:39,498 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, 'fetch_and_evaluate': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, 'fetch_and_evaluate.result': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, 'fetch_and_evaluate.status': 'success', 'result': {'logged': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'city_loop_results': [{'fetch_and_evaluate': {'city': 'London', 'max_temp': 25.1, 'alert': False}}, {'fetch_and_evaluate': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}}, {'fetch_and_evaluate': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}}], 'alerts': "[{'city': 'London', 'max_temp': 25.1, 'alert': False}, {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}]", 'aggregate_alerts': {'global_alert': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'aggregate_alerts.result': {'global_alert': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'aggregate_alerts.status': 'success', 'summary': {'alert_cities': ['Berlin'], 'count': 1}, 'log_aggregate_result': {'logged': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'log_aggregate_result.result': {'logged': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'log_aggregate_result.status': 'success'}
# [DEBUG] 2025-06-25T23:58:39,498 (noetl.agent:render_template:17) - Render template: {{ aggregate_alerts.summary }}
# [DEBUG] 2025-06-25T23:58:39,498 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status', 'summary', 'log_aggregate_result', 'log_aggregate_result.result', 'log_aggregate_result.status']
# [DEBUG] 2025-06-25T23:58:39,498 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:39,498 (noetl.agent:execute_step:1153) - Executing step: rendered_with={'summary': {'alert_cities': ['Berlin'], 'count': 1}}
# [DEBUG] 2025-06-25T23:58:39,499 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'London', 'lat': 51.51, 'lon': -0.13}, {'name': 'Paris', 'lat': 48.85, 'lon': 2.35}, {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 26}, 'execution_start': '2025-06-25T23:58:37.157293', 'city': {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, 'fetch_and_evaluate': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, 'fetch_and_evaluate.result': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, 'fetch_and_evaluate.status': 'success', 'result': {'logged': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'city_loop_results': [{'fetch_and_evaluate': {'city': 'London', 'max_temp': 25.1, 'alert': False}}, {'fetch_and_evaluate': {'city': 'Paris', 'max_temp': 25.6, 'alert': False}}, {'fetch_and_evaluate': {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}}], 'alerts': "[{'city': 'London', 'max_temp': 25.1, 'alert': False}, {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}]", 'aggregate_alerts': {'global_alert': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'aggregate_alerts.result': {'global_alert': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'aggregate_alerts.status': 'success', 'summary': {'alert_cities': ['Berlin'], 'count': 1}, 'log_aggregate_result': {'logged': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'log_aggregate_result.result': {'logged': True, 'summary': {'alert_cities': ['Berlin'], 'count': 1}}, 'log_aggregate_result.status': 'success'}
# [DEBUG] 2025-06-25T23:58:39,500 (noetl.agent:render_template:17) - Render template: {{ aggregate_alerts.summary }}
# [DEBUG] 2025-06-25T23:58:39,500 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status', 'summary', 'log_aggregate_result', 'log_aggregate_result.result', 'log_aggregate_result.status']
# [DEBUG] 2025-06-25T23:58:39,500 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:39,501 (noetl.agent:render_template:17) - Render template: {{ summary }}
# [DEBUG] 2025-06-25T23:58:39,501 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status', 'summary', 'log_aggregate_result', 'log_aggregate_result.result', 'log_aggregate_result.status']
# [DEBUG] 2025-06-25T23:58:39,501 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:39,501 (noetl.agent:render_template:17) - Render template: {{ summary }}
# [DEBUG] 2025-06-25T23:58:39,501 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'alerts', 'aggregate_alerts', 'aggregate_alerts.result', 'aggregate_alerts.status', 'summary', 'log_aggregate_result', 'log_aggregate_result.result', 'log_aggregate_result.status']
# [DEBUG] 2025-06-25T23:58:39,501 (noetl.agent:render_template:20) - Render template city value: {'name': 'Berlin', 'lat': 52.52, 'lon': 13.41}, Type: <class 'dict'>
# [ERROR] 2025-06-25T23:58:39,989 (noetl.agent:execute_python_task:1030) - Python task execution error: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# Traceback (most recent call last):
#   File "/Users/akuksin/projects/noetl/noetl/noetl/agent.py", line 998, in execute_python_task
#     result_data = exec_locals['main'](**task_with)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 7, in main
# duckdb.duckdb.IOException: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# [ERROR] 2025-06-25T23:58:40,000 (noetl.agent:run:1592) - Step failed: store_aggregate_result, error: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# [INFO] 2025-06-25T23:58:40,001 (noetl.agent:run:1701) - Playbook execution completed
# ℹ️ [INFO]  (main:run_agent:261)
#      Message: {
#                "fetch_and_evaluate": {
#                  "city": "London",
#                  "max_temp": 25.1,
#                  "alert": false
#                },
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "London",
#                      "max_temp": 25.1,
#                      "alert": false
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "Paris",
#                      "max_temp": 25.6,
#                      "alert": false
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "Berlin",
#                      "max_temp": 30.6,
#                      "alert": true
#                    }
#                  }
#                ],
#                "aggregate_alerts": {
#                  "global_alert": true,
#                  "summary": {
#                    "alert_cities": [
#                      "Berlin"
#                    ],
#                    "count": 1
#                  }
#                },
#                "end_city_loop": {
#                  "alerts": "[{'city': 'London', 'max_temp': 25.1, 'alert': False}, {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}]"
#                },
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [
#                      "Berlin"
#                    ],
#                    "count": 1
#                  }
#                },
#                "start": {}
#              }
# ℹ️ [INFO]  (main:run_agent:266)
#      Message: PostgreSQL connection: dbname=noetl user=noetl password=noetl host=localhost port=5434
# ℹ️ [INFO]  (main:run_agent:267)
#      Message: Open notebook/agent_mission_report.ipynb and set 'pgdb' to dbname=noetl user=noetl password=noetl host=localhost port=5434

# %% [markdown]
# With all options:

# %%
# !noetl agent \
  -f ../catalog/playbooks/weather_example.yaml \
  --mock \
  -o plain \
  --export ../data/exports/execution_data.parquet \
  --mlflow \
  --pgdb "dbname=noetl user=noetl password=noetl host=localhost port=5434" \
  --input ../data/input/payload.json \
  --debug
# Out:
# ℹ️ [INFO]  (main:run_agent:211)
#      Message: Loaded input payload from ../data/input/payload.json
# [INFO] 2025-06-25T23:58:46,309 (noetl.agent:__init__:97) - Modified Postgres: dbname=noetl user=noetl password=noetl host=localhost port=5434
# [INFO] 2025-06-25T23:58:46,325 (noetl.agent:init_database:127) - Initializing database tables
# [INFO] 2025-06-25T23:58:46,326 (noetl.agent:init_database:135) - Database connection is working
# [INFO] 2025-06-25T23:58:46,326 (noetl.agent:init_database:144) - Creating workload table if it doesn't exist
# [INFO] 2025-06-25T23:58:46,328 (noetl.agent:init_database:165) - Workload table exists or was created successfully
# [INFO] 2025-06-25T23:58:46,328 (noetl.agent:init_database:171) - Testing workload table with test_id: test_96f8f594-ced2-4cb2-b30e-f8dc6c2a3971
# [INFO] 2025-06-25T23:58:46,329 (noetl.agent:init_database:188) - Successfully tested workload table insert and select
# [INFO] 2025-06-25T23:58:46,330 (noetl.agent:init_database:197) - Cleaned up test data from workload table
# [INFO] 2025-06-25T23:58:46,330 (noetl.agent:init_database:202) - Creating event_log table if it doesn't exist
# [INFO] 2025-06-25T23:58:46,331 (noetl.agent:init_database:235) - Creating workflow table if it doesn't exist
# [INFO] 2025-06-25T23:58:46,331 (noetl.agent:init_database:249) - Creating workbook table if it doesn't exist
# [INFO] 2025-06-25T23:58:46,331 (noetl.agent:init_database:262) - Creating transition table if it doesn't exist
# [INFO] 2025-06-25T23:58:46,332 (noetl.agent:init_database:276) - Database tables initialized successfully
# [INFO] 2025-06-25T23:58:46,333 (noetl.agent:init_database:285) - Tables in database: ['test_data_table', 'resource', 'catalog', 'event_log', 'workflow', 'workbook', 'workload', 'transition', 'weather_alert_summary']
# [INFO] 2025-06-25T23:58:46,333 (noetl.agent:load_workload:374) - Loading workload data for execution 9c74df9b-5d4b-4701-8747-f7d1087c2892
# [INFO] 2025-06-25T23:58:46,333 (noetl.agent:load_workload:377) - Checking if workload table exists
# [INFO] 2025-06-25T23:58:46,333 (noetl.agent:load_workload:389) - Workload table exists in the database
# [INFO] 2025-06-25T23:58:46,333 (noetl.agent:load_workload:392) - Checking if workload table has any rows
# [INFO] 2025-06-25T23:58:46,334 (noetl.agent:load_workload:395) - Total rows in workload table: 17
# [INFO] 2025-06-25T23:58:46,334 (noetl.agent:load_workload:398) - Querying workload data for execution_id: 9c74df9b-5d4b-4701-8747-f7d1087c2892
# [INFO] 2025-06-25T23:58:46,334 (noetl.agent:load_workload:417) - No workload data found for execution 9c74df9b-5d4b-4701-8747-f7d1087c2892
# [INFO] 2025-06-25T23:58:46,334 (noetl.agent:load_workload:422) - All execution_ids in workload table: ['25bb3c66-1b70-4d01-bd59-779406528dcd', '42e713db-8899-47d2-b51d-636c945069d6', '3bc0666d-fd86-4085-abde-868ce4fdf35e', 'a6cf6cec-a8bb-4dc7-881a-772ea5fee322', 'fa360edb-d6e2-48d1-988c-0a9fe85b46e1', 'a927af04-7662-42ec-89db-64be0e790ed0', '98221acf-ae4a-40ff-bc39-d60e98ac6381', 'e9ecdcaa-dd28-40f3-bc1d-cd9786a44253', '2cc0d5ea-3ab3-4f4c-85d2-de08883a060b', '6f494720-5d00-4c5d-8eb0-099115128e9f', '0fa4ac45-816c-41a1-9aa1-3b7d7159fab3', '6f712950-83b4-4ea6-bc7a-ea0159044c18', '3251ffb7-1380-48db-b77c-ebb0431c1819', '0235a657-49ed-4039-8f88-8712260ccac1', 'c9162f63-015b-496c-be00-ac5897df98a3', '5c8dcd32-e61a-47b0-88ef-9f855ec59d89', 'aa6a4b5a-2cf6-4854-92bd-862b37ba116b']
# [INFO] 2025-06-25T23:58:46,334 (noetl.agent:__init__:108) - Workload not found in database. Using default from playbook.
# ℹ️ [INFO]  (main:run_agent:240)
#      Message: Override mode: replacing specific workload keys with input payload
# [INFO] 2025-06-25T23:58:46,353 (noetl.agent:store_workload:306) - Storing workload data for execution 9c74df9b-5d4b-4701-8747-f7d1087c2892: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "New York", "lat": 40.71, "lon": -...
# [INFO] 2025-06-25T23:58:46,354 (noetl.agent:store_workload:332) - Executing INSERT INTO workload for execution_id: 9c74df9b-5d4b-4701-8747-f7d1087c2892
# [INFO] 2025-06-25T23:58:46,355 (noetl.agent:store_workload:340) - INSERT INTO workload completed and committed for execution_id: 9c74df9b-5d4b-4701-8747-f7d1087c2892
# [INFO] 2025-06-25T23:58:46,355 (noetl.agent:store_workload:343) - Verifying data was stored for execution_id: 9c74df9b-5d4b-4701-8747-f7d1087c2892
# [INFO] 2025-06-25T23:58:46,356 (noetl.agent:store_workload:351) - Successfully stored workload data for execution 9c74df9b-5d4b-4701-8747-f7d1087c2892. Found 1 rows.
# [INFO] 2025-06-25T23:58:46,356 (noetl.agent:store_workload:359) - Retrieved workload data for execution 9c74df9b-5d4b-4701-8747-f7d1087c2892: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "New York", "lat": 40.71, "lon": -...
# [INFO] 2025-06-25T23:58:46,356 (noetl.agent:run:1560) - Starting playbook: weather_example
# [INFO] 2025-06-25T23:58:46,358 (noetl.agent:execute_step:1147) - Executing step: start
# [DEBUG] 2025-06-25T23:58:46,358 (noetl.agent:execute_step:1148) - Executing step: step_name=start, step_with=None
# [DEBUG] 2025-06-25T23:58:46,358 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499'}
# [DEBUG] 2025-06-25T23:58:46,358 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499'}
# [DEBUG] 2025-06-25T23:58:46,363 (noetl.agent:render_template:17) - Render template: {{ workload.state == 'ready' }}
# [DEBUG] 2025-06-25T23:58:46,363 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start']
# [DEBUG] 2025-06-25T23:58:46,364 (noetl.agent:render_template:17) - Render template: {{ workload.state == 'ready' }}
# [DEBUG] 2025-06-25T23:58:46,364 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start']
# [INFO] 2025-06-25T23:58:46,367 (noetl.agent:execute_step:1147) - Executing step: city_loop
# [DEBUG] 2025-06-25T23:58:46,367 (noetl.agent:execute_step:1148) - Executing step: step_name=city_loop, step_with={}
# [DEBUG] 2025-06-25T23:58:46,367 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499'}
# [DEBUG] 2025-06-25T23:58:46,367 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499'}
# [DEBUG] 2025-06-25T23:58:46,368 (noetl.agent:render_template:17) - Render template: {{ workload.cities }}
# [DEBUG] 2025-06-25T23:58:46,368 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start']
# [INFO] 2025-06-25T23:58:46,368 (noetl.agent:execute_loop_step:1353) - Starting loop step with 1 items
# [DEBUG] 2025-06-25T23:58:46,368 (noetl.agent:execute_loop_step:1354) - Loop step iterator=city, items=[{'name': 'New York', 'lat': 40.71, 'lon': -74.01}]
# [DEBUG] 2025-06-25T23:58:46,369 (noetl.agent:render_template:17) - Render template: {{}}
# [DEBUG] 2025-06-25T23:58:46,369 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:46,369 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,369 (noetl.agent:execute_loop_step:1414) - Loop next step: fetch_and_evaluate, next_step_with={'city': '{{ city }}', 'base_url': '{{ workload.base_url }}', 'temperature_threshold': '{{ temperature_threshold }}'}, rules={'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}}
# [DEBUG] 2025-06-25T23:58:46,369 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:17) - Render template: {{ workload.base_url }}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:render_template:22) - Render template rules: {'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:execute_loop_step:1417) - Loop step rendered with: {'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}
# [INFO] 2025-06-25T23:58:46,370 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:execute_step:1148) - Executing step: step_name=fetch_and_evaluate, step_with={'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499'}
# [DEBUG] 2025-06-25T23:58:46,370 (noetl.agent:execute_step:1153) - Executing step: rendered_with={'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}
# [DEBUG] 2025-06-25T23:58:46,372 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499', 'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}}
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city']
# [DEBUG] 2025-06-25T23:58:46,373 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'threshold']
# [DEBUG] 2025-06-25T23:58:46,374 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:46,422 (httpcore.connection:trace:47) - connect_tcp.started host='api.open-meteo.com' port=443 local_address=None timeout=5.0 socket_options=None
# [DEBUG] 2025-06-25T23:58:46,595 (httpcore.connection:trace:47) - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x108ee1790>
# [DEBUG] 2025-06-25T23:58:46,595 (httpcore.connection:trace:47) - start_tls.started ssl_context=<ssl.SSLContext object at 0x108ef1e50> server_hostname='api.open-meteo.com' timeout=5.0
# [DEBUG] 2025-06-25T23:58:46,936 (httpcore.connection:trace:47) - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x108cdff50>
# [DEBUG] 2025-06-25T23:58:46,937 (httpcore.http11:trace:47) - send_request_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:46,937 (httpcore.http11:trace:47) - send_request_headers.complete
# [DEBUG] 2025-06-25T23:58:46,937 (httpcore.http11:trace:47) - send_request_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:46,937 (httpcore.http11:trace:47) - send_request_body.complete
# [DEBUG] 2025-06-25T23:58:46,937 (httpcore.http11:trace:47) - receive_response_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:47,105 (httpcore.http11:trace:47) - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 26 Jun 2025 06:58:47 GMT'), (b'Content-Type', b'application/json; charset=utf-8'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'deflate')])
# [INFO] 2025-06-25T23:58:47,105 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=40.71&longitude=-74.01&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [DEBUG] 2025-06-25T23:58:47,106 (httpcore.http11:trace:47) - receive_response_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:47,106 (httpcore.http11:trace:47) - receive_response_body.complete
# [DEBUG] 2025-06-25T23:58:47,106 (httpcore.http11:trace:47) - response_closed.started
# [DEBUG] 2025-06-25T23:58:47,106 (httpcore.http11:trace:47) - response_closed.complete
# [DEBUG] 2025-06-25T23:58:47,106 (httpcore.connection:trace:47) - close.started
# [DEBUG] 2025-06-25T23:58:47,106 (httpcore.connection:trace:47) - close.complete
# [INFO] 2025-06-25T23:58:47,133 (noetl.agent:execute_loop_step:1455) - Found end_loop step for city_loop: end_city_loop
# [INFO] 2025-06-25T23:58:47,139 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:execute_step:1148) - Executing step: step_name=fetch_and_evaluate, step_with={'city': '{{ city }}', 'base_url': '{{ workload.base_url }}', 'temperature_threshold': '{{ temperature_threshold }}'}
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:execute_step:1149) - Executing step: context before update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499', 'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, 'fetch_and_evaluate': {'city': 'New York', 'max_temp': 34.8, 'alert': True}, 'fetch_and_evaluate.result': {'city': 'New York', 'max_temp': 34.8, 'alert': True}, 'fetch_and_evaluate.status': 'success', 'result': {'city': 'New York', 'max_temp': 34.8, 'alert': True}, 'city_loop_results': [{'fetch_and_evaluate': {'city': 'New York', 'max_temp': 34.8, 'alert': True}}]}
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results']
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:17) - Render template: {{ workload.base_url }}
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results']
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results']
# [DEBUG] 2025-06-25T23:58:47,139 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,140 (noetl.agent:execute_step:1153) - Executing step: rendered_with={'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}
# [DEBUG] 2025-06-25T23:58:47,144 (noetl.agent:execute_step:1159) - Executing step: context after update: {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20, 'workload': {'jobId': '{{ job.uuid }}', 'state': 'ready', 'cities': [{'name': 'New York', 'lat': 40.71, 'lon': -74.01}], 'base_url': 'https://api.open-meteo.com/v1', 'temperature_threshold': 20}, 'execution_start': '2025-06-25T23:58:46.356499', 'city': {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, 'fetch_and_evaluate': {'city': 'New York', 'max_temp': 34.8, 'alert': True}, 'fetch_and_evaluate.result': {'city': 'New York', 'max_temp': 34.8, 'alert': True}, 'fetch_and_evaluate.status': 'success', 'result': {'city': 'New York', 'max_temp': 34.8, 'alert': True}, 'city_loop_results': [{'fetch_and_evaluate': {'city': 'New York', 'max_temp': 34.8, 'alert': True}}]}
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results']
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results']
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:17) - Render template: {{ temperature_threshold }}
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results']
# [DEBUG] 2025-06-25T23:58:47,146 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'threshold']
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'threshold']
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'threshold']
# [DEBUG] 2025-06-25T23:58:47,147 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:17) - Render template: {{ city }}
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'threshold']
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:17) - Render template: {{ threshold }}
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'threshold']
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:17) - Render template: {{ base_url }}
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results', 'threshold']
# [DEBUG] 2025-06-25T23:58:47,148 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [DEBUG] 2025-06-25T23:58:47,156 (httpcore.connection:trace:47) - connect_tcp.started host='api.open-meteo.com' port=443 local_address=None timeout=5.0 socket_options=None
# [DEBUG] 2025-06-25T23:58:47,322 (httpcore.connection:trace:47) - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x108f0bda0>
# [DEBUG] 2025-06-25T23:58:47,322 (httpcore.connection:trace:47) - start_tls.started ssl_context=<ssl.SSLContext object at 0x108ef28d0> server_hostname='api.open-meteo.com' timeout=5.0
# [DEBUG] 2025-06-25T23:58:47,658 (httpcore.connection:trace:47) - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x108f0bcb0>
# [DEBUG] 2025-06-25T23:58:47,658 (httpcore.http11:trace:47) - send_request_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:47,659 (httpcore.http11:trace:47) - send_request_headers.complete
# [DEBUG] 2025-06-25T23:58:47,659 (httpcore.http11:trace:47) - send_request_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:47,659 (httpcore.http11:trace:47) - send_request_body.complete
# [DEBUG] 2025-06-25T23:58:47,659 (httpcore.http11:trace:47) - receive_response_headers.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:47,822 (httpcore.http11:trace:47) - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 26 Jun 2025 06:58:47 GMT'), (b'Content-Type', b'application/json; charset=utf-8'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Content-Encoding', b'deflate')])
# [INFO] 2025-06-25T23:58:47,823 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=40.71&longitude=-74.01&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [DEBUG] 2025-06-25T23:58:47,823 (httpcore.http11:trace:47) - receive_response_body.started request=<Request [b'GET']>
# [DEBUG] 2025-06-25T23:58:47,823 (httpcore.http11:trace:47) - receive_response_body.complete
# [DEBUG] 2025-06-25T23:58:47,823 (httpcore.http11:trace:47) - response_closed.started
# [DEBUG] 2025-06-25T23:58:47,823 (httpcore.http11:trace:47) - response_closed.complete
# [DEBUG] 2025-06-25T23:58:47,823 (httpcore.connection:trace:47) - close.started
# [DEBUG] 2025-06-25T23:58:47,823 (httpcore.connection:trace:47) - close.complete
# [DEBUG] 2025-06-25T23:58:47,831 (noetl.agent:render_template:17) - Render template: {{ evaluate_weather_directly.alert }}
# [DEBUG] 2025-06-25T23:58:47,831 (noetl.agent:render_template:18) - Render template context keys: ['jobId', 'state', 'cities', 'base_url', 'temperature_threshold', 'workload', 'execution_start', 'city', 'fetch_and_evaluate', 'fetch_and_evaluate.result', 'fetch_and_evaluate.status', 'result', 'city_loop_results']
# [DEBUG] 2025-06-25T23:58:47,831 (noetl.agent:render_template:20) - Render template city value: {'name': 'New York', 'lat': 40.71, 'lon': -74.01}, Type: <class 'dict'>
# [ERROR] 2025-06-25T23:58:47,833 (noetl.agent:render_template:56) - Template rendering error: 'evaluate_weather_directly' is undefined, template: {{ evaluate_weather_directly.alert }}
# [INFO] 2025-06-25T23:58:47,834 (noetl.agent:run:1701) - Playbook execution completed
# [INFO] 2025-06-25T23:58:47,838 (noetl.agent:export_execution_data:1553) - Execution data exported to ../data/exports/execution_data.parquet
# ℹ️ [INFO]  (main:run_agent:264)
#      Message: start: {}
# ℹ️ [INFO]  (main:run_agent:264)
#      Message: fetch_and_evaluate: {'city': 'New York', 'max_temp': 34.8, 'alert': True}
# ℹ️ [INFO]  (main:run_agent:264)
#      Message: city_loop: [{'fetch_and_evaluate': {'city': 'New York', 'max_temp': 34.8, 'alert': True}}]
# ℹ️ [INFO]  (main:run_agent:266)
#      Message: PostgreSQL connection: dbname=noetl user=noetl password=noetl host=localhost port=5434
# ℹ️ [INFO]  (main:run_agent:267)
#      Message: Open notebook/agent_mission_report.ipynb and set 'pgdb' to dbname=noetl user=noetl password=noetl host=localhost port=5434

# %% [markdown]
# Command line with payload:

# %%
# !noetl agent \
  -f ../catalog/playbooks/weather_example.yaml \
  --payload '{"cities": [{"name": "New York", "lat": 40.71, "lon": -74.01}], "temperature_threshold": 20}'
# Out:
# ℹ️ [INFO]  (main:run_agent:218)
#      Message: Parsed input payload from command line
# ℹ️ [INFO]  (main:run_agent:226)
#      Message: Using default PostgreSQL connection string: dbname=noetl user=noetl password=noetl host=localhost port=5434
# [INFO] 2025-06-25T23:58:52,712 (noetl.agent:__init__:97) - Modified Postgres: dbname=noetl user=noetl password=noetl host=localhost port=5434
# [INFO] 2025-06-25T23:58:52,727 (noetl.agent:init_database:127) - Initializing database tables
# [INFO] 2025-06-25T23:58:52,728 (noetl.agent:init_database:135) - Database connection is working
# [INFO] 2025-06-25T23:58:52,728 (noetl.agent:init_database:144) - Creating workload table if it doesn't exist
# [INFO] 2025-06-25T23:58:52,730 (noetl.agent:init_database:165) - Workload table exists or was created successfully
# [INFO] 2025-06-25T23:58:52,730 (noetl.agent:init_database:171) - Testing workload table with test_id: test_3024773e-30e1-4420-87aa-f918a24f84ce
# [INFO] 2025-06-25T23:58:52,732 (noetl.agent:init_database:188) - Successfully tested workload table insert and select
# [INFO] 2025-06-25T23:58:52,732 (noetl.agent:init_database:197) - Cleaned up test data from workload table
# [INFO] 2025-06-25T23:58:52,732 (noetl.agent:init_database:202) - Creating event_log table if it doesn't exist
# [INFO] 2025-06-25T23:58:52,733 (noetl.agent:init_database:235) - Creating workflow table if it doesn't exist
# [INFO] 2025-06-25T23:58:52,733 (noetl.agent:init_database:249) - Creating workbook table if it doesn't exist
# [INFO] 2025-06-25T23:58:52,734 (noetl.agent:init_database:262) - Creating transition table if it doesn't exist
# [INFO] 2025-06-25T23:58:52,734 (noetl.agent:init_database:276) - Database tables initialized successfully
# [INFO] 2025-06-25T23:58:52,735 (noetl.agent:init_database:285) - Tables in database: ['test_data_table', 'resource', 'catalog', 'event_log', 'workflow', 'workbook', 'workload', 'transition', 'weather_alert_summary']
# [INFO] 2025-06-25T23:58:52,735 (noetl.agent:load_workload:374) - Loading workload data for execution 1c115a66-3d40-40f0-9f40-a94be04b4161
# [INFO] 2025-06-25T23:58:52,735 (noetl.agent:load_workload:377) - Checking if workload table exists
# [INFO] 2025-06-25T23:58:52,736 (noetl.agent:load_workload:389) - Workload table exists in the database
# [INFO] 2025-06-25T23:58:52,736 (noetl.agent:load_workload:392) - Checking if workload table has any rows
# [INFO] 2025-06-25T23:58:52,736 (noetl.agent:load_workload:395) - Total rows in workload table: 18
# [INFO] 2025-06-25T23:58:52,736 (noetl.agent:load_workload:398) - Querying workload data for execution_id: 1c115a66-3d40-40f0-9f40-a94be04b4161
# [INFO] 2025-06-25T23:58:52,737 (noetl.agent:load_workload:417) - No workload data found for execution 1c115a66-3d40-40f0-9f40-a94be04b4161
# [INFO] 2025-06-25T23:58:52,737 (noetl.agent:load_workload:422) - All execution_ids in workload table: ['25bb3c66-1b70-4d01-bd59-779406528dcd', '42e713db-8899-47d2-b51d-636c945069d6', '3bc0666d-fd86-4085-abde-868ce4fdf35e', 'a6cf6cec-a8bb-4dc7-881a-772ea5fee322', 'fa360edb-d6e2-48d1-988c-0a9fe85b46e1', 'a927af04-7662-42ec-89db-64be0e790ed0', '98221acf-ae4a-40ff-bc39-d60e98ac6381', 'e9ecdcaa-dd28-40f3-bc1d-cd9786a44253', '2cc0d5ea-3ab3-4f4c-85d2-de08883a060b', '6f494720-5d00-4c5d-8eb0-099115128e9f', '0fa4ac45-816c-41a1-9aa1-3b7d7159fab3', '6f712950-83b4-4ea6-bc7a-ea0159044c18', '3251ffb7-1380-48db-b77c-ebb0431c1819', '0235a657-49ed-4039-8f88-8712260ccac1', 'c9162f63-015b-496c-be00-ac5897df98a3', '5c8dcd32-e61a-47b0-88ef-9f855ec59d89', 'aa6a4b5a-2cf6-4854-92bd-862b37ba116b', '9c74df9b-5d4b-4701-8747-f7d1087c2892']
# [INFO] 2025-06-25T23:58:52,737 (noetl.agent:__init__:108) - Workload not found in database. Using default from playbook.
# ℹ️ [INFO]  (main:run_agent:240)
#      Message: Override mode: replacing specific workload keys with input payload
# [INFO] 2025-06-25T23:58:52,754 (noetl.agent:store_workload:306) - Storing workload data for execution 1c115a66-3d40-40f0-9f40-a94be04b4161: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "New York", "lat": 40.71, "lon": -...
# [INFO] 2025-06-25T23:58:52,755 (noetl.agent:store_workload:332) - Executing INSERT INTO workload for execution_id: 1c115a66-3d40-40f0-9f40-a94be04b4161
# [INFO] 2025-06-25T23:58:52,756 (noetl.agent:store_workload:340) - INSERT INTO workload completed and committed for execution_id: 1c115a66-3d40-40f0-9f40-a94be04b4161
# [INFO] 2025-06-25T23:58:52,756 (noetl.agent:store_workload:343) - Verifying data was stored for execution_id: 1c115a66-3d40-40f0-9f40-a94be04b4161
# [INFO] 2025-06-25T23:58:52,757 (noetl.agent:store_workload:351) - Successfully stored workload data for execution 1c115a66-3d40-40f0-9f40-a94be04b4161. Found 1 rows.
# [INFO] 2025-06-25T23:58:52,757 (noetl.agent:store_workload:359) - Retrieved workload data for execution 1c115a66-3d40-40f0-9f40-a94be04b4161: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "New York", "lat": 40.71, "lon": -...
# [INFO] 2025-06-25T23:58:52,757 (noetl.agent:run:1560) - Starting playbook: weather_example
# [INFO] 2025-06-25T23:58:52,759 (noetl.agent:execute_step:1147) - Executing step: start
# [INFO] 2025-06-25T23:58:52,767 (noetl.agent:execute_step:1147) - Executing step: city_loop
# [INFO] 2025-06-25T23:58:52,768 (noetl.agent:execute_loop_step:1353) - Starting loop step with 1 items
# [INFO] 2025-06-25T23:58:52,771 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [INFO] 2025-06-25T23:58:53,490 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=40.71&longitude=-74.01&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [INFO] 2025-06-25T23:58:53,517 (noetl.agent:execute_loop_step:1455) - Found end_loop step for city_loop: end_city_loop
# [INFO] 2025-06-25T23:58:53,519 (noetl.agent:run:1646) - Using next_step from step result: end_city_loop
# [INFO] 2025-06-25T23:58:53,524 (noetl.agent:execute_step:1147) - Executing step: end_city_loop
# [INFO] 2025-06-25T23:58:53,525 (noetl.agent:end_loop_step:1237) - Processing end_loop for: city_loop
# [INFO] 2025-06-25T23:58:53,539 (noetl.agent:execute_step:1147) - Executing step: aggregate_alerts
# [INFO] 2025-06-25T23:58:53,555 (noetl.agent:execute_step:1147) - Executing step: log_aggregate_result
# Aggregated weather alert summary: {'alert_cities': ['New York'], 'count': 1}
# [INFO] 2025-06-25T23:58:53,569 (noetl.agent:execute_step:1147) - Executing step: store_aggregate_result
# [ERROR] 2025-06-25T23:58:53,641 (noetl.agent:execute_python_task:1030) - Python task execution error: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# Traceback (most recent call last):
#   File "/Users/akuksin/projects/noetl/noetl/noetl/agent.py", line 998, in execute_python_task
#     result_data = exec_locals['main'](**task_with)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 7, in main
# duckdb.duckdb.IOException: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# [ERROR] 2025-06-25T23:58:53,652 (noetl.agent:run:1592) - Step failed: store_aggregate_result, error: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# [INFO] 2025-06-25T23:58:53,653 (noetl.agent:run:1701) - Playbook execution completed
# ℹ️ [INFO]  (main:run_agent:261)
#      Message: {
#                "start": {},
#                "aggregate_alerts": {
#                  "global_alert": true,
#                  "summary": {
#                    "alert_cities": [
#                      "New York"
#                    ],
#                    "count": 1
#                  }
#                },
#                "fetch_and_evaluate": {
#                  "city": "New York",
#                  "max_temp": 34.8,
#                  "alert": true
#                },
#                "end_city_loop": {
#                  "alerts": "[{'city': 'New York', 'max_temp': 34.8, 'alert': True}]"
#                },
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "New York",
#                      "max_temp": 34.8,
#                      "alert": true
#                    }
#                  }
#                ],
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [
#                      "New York"
#                    ],
#                    "count": 1
#                  }
#                }
#              }
# ℹ️ [INFO]  (main:run_agent:266)
#      Message: PostgreSQL connection: dbname=noetl user=noetl password=noetl host=localhost port=5434
# ℹ️ [INFO]  (main:run_agent:267)
#      Message: Open notebook/agent_mission_report.ipynb and set 'pgdb' to dbname=noetl user=noetl password=noetl host=localhost port=5434

# %% [markdown]
# Merge mode to merge payload input data with playbook's workload data:

# %%
# !noetl agent \
  -f ../catalog/playbooks/weather_example.yaml \
  --payload '{"cities": [{"name": "New York", "lat": 40.71, "lon": -74.01}], "temperature_threshold": 20}' \
  --merge
# Out:
# ℹ️ [INFO]  (main:run_agent:218)
#      Message: Parsed input payload from command line
# ℹ️ [INFO]  (main:run_agent:226)
#      Message: Using default PostgreSQL connection string: dbname=noetl user=noetl password=noetl host=localhost port=5434
# [INFO] 2025-06-25T23:58:57,225 (noetl.agent:__init__:97) - Modified Postgres: dbname=noetl user=noetl password=noetl host=localhost port=5434
# [INFO] 2025-06-25T23:58:57,241 (noetl.agent:init_database:127) - Initializing database tables
# [INFO] 2025-06-25T23:58:57,242 (noetl.agent:init_database:135) - Database connection is working
# [INFO] 2025-06-25T23:58:57,242 (noetl.agent:init_database:144) - Creating workload table if it doesn't exist
# [INFO] 2025-06-25T23:58:57,244 (noetl.agent:init_database:165) - Workload table exists or was created successfully
# [INFO] 2025-06-25T23:58:57,244 (noetl.agent:init_database:171) - Testing workload table with test_id: test_1a4f03e2-98c6-49df-8ab0-87ad53361a7a
# [INFO] 2025-06-25T23:58:57,245 (noetl.agent:init_database:188) - Successfully tested workload table insert and select
# [INFO] 2025-06-25T23:58:57,246 (noetl.agent:init_database:197) - Cleaned up test data from workload table
# [INFO] 2025-06-25T23:58:57,246 (noetl.agent:init_database:202) - Creating event_log table if it doesn't exist
# [INFO] 2025-06-25T23:58:57,247 (noetl.agent:init_database:235) - Creating workflow table if it doesn't exist
# [INFO] 2025-06-25T23:58:57,247 (noetl.agent:init_database:249) - Creating workbook table if it doesn't exist
# [INFO] 2025-06-25T23:58:57,247 (noetl.agent:init_database:262) - Creating transition table if it doesn't exist
# [INFO] 2025-06-25T23:58:57,248 (noetl.agent:init_database:276) - Database tables initialized successfully
# [INFO] 2025-06-25T23:58:57,249 (noetl.agent:init_database:285) - Tables in database: ['test_data_table', 'resource', 'catalog', 'event_log', 'workflow', 'workbook', 'workload', 'transition', 'weather_alert_summary']
# [INFO] 2025-06-25T23:58:57,249 (noetl.agent:load_workload:374) - Loading workload data for execution f4c00c11-dfd5-4c88-bd02-4235db6be02a
# [INFO] 2025-06-25T23:58:57,249 (noetl.agent:load_workload:377) - Checking if workload table exists
# [INFO] 2025-06-25T23:58:57,249 (noetl.agent:load_workload:389) - Workload table exists in the database
# [INFO] 2025-06-25T23:58:57,249 (noetl.agent:load_workload:392) - Checking if workload table has any rows
# [INFO] 2025-06-25T23:58:57,250 (noetl.agent:load_workload:395) - Total rows in workload table: 19
# [INFO] 2025-06-25T23:58:57,250 (noetl.agent:load_workload:398) - Querying workload data for execution_id: f4c00c11-dfd5-4c88-bd02-4235db6be02a
# [INFO] 2025-06-25T23:58:57,250 (noetl.agent:load_workload:417) - No workload data found for execution f4c00c11-dfd5-4c88-bd02-4235db6be02a
# [INFO] 2025-06-25T23:58:57,250 (noetl.agent:load_workload:422) - All execution_ids in workload table: ['25bb3c66-1b70-4d01-bd59-779406528dcd', '42e713db-8899-47d2-b51d-636c945069d6', '3bc0666d-fd86-4085-abde-868ce4fdf35e', 'a6cf6cec-a8bb-4dc7-881a-772ea5fee322', 'fa360edb-d6e2-48d1-988c-0a9fe85b46e1', 'a927af04-7662-42ec-89db-64be0e790ed0', '98221acf-ae4a-40ff-bc39-d60e98ac6381', 'e9ecdcaa-dd28-40f3-bc1d-cd9786a44253', '2cc0d5ea-3ab3-4f4c-85d2-de08883a060b', '6f494720-5d00-4c5d-8eb0-099115128e9f', '0fa4ac45-816c-41a1-9aa1-3b7d7159fab3', '6f712950-83b4-4ea6-bc7a-ea0159044c18', '3251ffb7-1380-48db-b77c-ebb0431c1819', '0235a657-49ed-4039-8f88-8712260ccac1', 'c9162f63-015b-496c-be00-ac5897df98a3', '5c8dcd32-e61a-47b0-88ef-9f855ec59d89', 'aa6a4b5a-2cf6-4854-92bd-862b37ba116b', '9c74df9b-5d4b-4701-8747-f7d1087c2892', '1c115a66-3d40-40f0-9f40-a94be04b4161']
# [INFO] 2025-06-25T23:58:57,250 (noetl.agent:__init__:108) - Workload not found in database. Using default from playbook.
# ℹ️ [INFO]  (main:run_agent:233)
#      Message: Merge mode: deep merging input payload with workload
# [INFO] 2025-06-25T23:58:57,266 (noetl.agent:store_workload:306) - Storing workload data for execution f4c00c11-dfd5-4c88-bd02-4235db6be02a: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "London", "lat": 51.51, "lon": -0....
# [INFO] 2025-06-25T23:58:57,267 (noetl.agent:store_workload:332) - Executing INSERT INTO workload for execution_id: f4c00c11-dfd5-4c88-bd02-4235db6be02a
# [INFO] 2025-06-25T23:58:57,268 (noetl.agent:store_workload:340) - INSERT INTO workload completed and committed for execution_id: f4c00c11-dfd5-4c88-bd02-4235db6be02a
# [INFO] 2025-06-25T23:58:57,268 (noetl.agent:store_workload:343) - Verifying data was stored for execution_id: f4c00c11-dfd5-4c88-bd02-4235db6be02a
# [INFO] 2025-06-25T23:58:57,269 (noetl.agent:store_workload:351) - Successfully stored workload data for execution f4c00c11-dfd5-4c88-bd02-4235db6be02a. Found 1 rows.
# [INFO] 2025-06-25T23:58:57,270 (noetl.agent:store_workload:359) - Retrieved workload data for execution f4c00c11-dfd5-4c88-bd02-4235db6be02a: {"jobId": "{{ job.uuid }}", "state": "ready", "cities": [{"name": "London", "lat": 51.51, "lon": -0....
# [INFO] 2025-06-25T23:58:57,270 (noetl.agent:run:1560) - Starting playbook: weather_example
# [INFO] 2025-06-25T23:58:57,271 (noetl.agent:execute_step:1147) - Executing step: start
# [INFO] 2025-06-25T23:58:57,279 (noetl.agent:execute_step:1147) - Executing step: city_loop
# [INFO] 2025-06-25T23:58:57,281 (noetl.agent:execute_loop_step:1353) - Starting loop step with 4 items
# [INFO] 2025-06-25T23:58:57,283 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [INFO] 2025-06-25T23:58:58,027 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=51.51&longitude=-0.13&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [INFO] 2025-06-25T23:58:58,062 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [INFO] 2025-06-25T23:58:58,753 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [INFO] 2025-06-25T23:58:58,766 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [INFO] 2025-06-25T23:58:59,479 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [INFO] 2025-06-25T23:58:59,501 (noetl.agent:execute_step:1147) - Executing step: fetch_and_evaluate
# [INFO] 2025-06-25T23:59:00,204 (httpx:_send_single_request:1025) - HTTP Request: GET https://api.open-meteo.com/v1/forecast?latitude=40.71&longitude=-74.01&hourly=temperature_2m&forecast_days=1 "HTTP/1.1 200 OK"
# [INFO] 2025-06-25T23:59:00,218 (noetl.agent:execute_loop_step:1455) - Found end_loop step for city_loop: end_city_loop
# [INFO] 2025-06-25T23:59:00,219 (noetl.agent:run:1646) - Using next_step from step result: end_city_loop
# [INFO] 2025-06-25T23:59:00,225 (noetl.agent:execute_step:1147) - Executing step: end_city_loop
# [INFO] 2025-06-25T23:59:00,227 (noetl.agent:end_loop_step:1237) - Processing end_loop for: city_loop
# [INFO] 2025-06-25T23:59:00,240 (noetl.agent:execute_step:1147) - Executing step: aggregate_alerts
# [INFO] 2025-06-25T23:59:00,255 (noetl.agent:execute_step:1147) - Executing step: log_aggregate_result
# Aggregated weather alert summary: {'alert_cities': ['London', 'Paris', 'Berlin', 'New York'], 'count': 4}
# [INFO] 2025-06-25T23:59:00,271 (noetl.agent:execute_step:1147) - Executing step: store_aggregate_result
# [ERROR] 2025-06-25T23:59:00,298 (noetl.agent:execute_python_task:1030) - Python task execution error: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# Traceback (most recent call last):
#   File "/Users/akuksin/projects/noetl/noetl/noetl/agent.py", line 998, in execute_python_task
#     result_data = exec_locals['main'](**task_with)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 7, in main
# duckdb.duckdb.IOException: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# [ERROR] 2025-06-25T23:59:00,311 (noetl.agent:run:1592) - Step failed: store_aggregate_result, error: IO Error: Cannot open file "/Users/akuksin/projects/noetl/noetl/notebook/./data/noetldb/postgres_pipeline.duckdb": No such file or directory
# [INFO] 2025-06-25T23:59:00,315 (noetl.agent:run:1701) - Playbook execution completed
# ℹ️ [INFO]  (main:run_agent:261)
#      Message: {
#                "start": {},
#                "aggregate_alerts": {
#                  "global_alert": true,
#                  "summary": {
#                    "alert_cities": [
#                      "London",
#                      "Paris",
#                      "Berlin",
#                      "New York"
#                    ],
#                    "count": 4
#                  }
#                },
#                "fetch_and_evaluate": {
#                  "city": "Paris",
#                  "max_temp": 25.6,
#                  "alert": true
#                },
#                "end_city_loop": {
#                  "alerts": "[{'city': 'London', 'max_temp': 25.1, 'alert': True}, {'city': 'Paris', 'max_temp': 25.6, 'alert': True}, {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, {'city': 'New York', 'max_temp': 34.8, 'alert': True}]"
#                },
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "London",
#                      "max_temp": 25.1,
#                      "alert": true
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "Paris",
#                      "max_temp": 25.6,
#                      "alert": true
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "Berlin",
#                      "max_temp": 30.6,
#                      "alert": true
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "New York",
#                      "max_temp": 34.8,
#                      "alert": true
#                    }
#                  }
#                ],
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [
#                      "London",
#                      "Paris",
#                      "Berlin",
#                      "New York"
#                    ],
#                    "count": 4
#                  }
#                }
#              }
# ℹ️ [INFO]  (main:run_agent:266)
#      Message: PostgreSQL connection: dbname=noetl user=noetl password=noetl host=localhost port=5434
# ℹ️ [INFO]  (main:run_agent:267)
#      Message: Open notebook/agent_mission_report.ipynb and set 'pgdb' to dbname=noetl user=noetl password=noetl host=localhost port=5434

# %% [markdown]
# ## 2. Using the Test Script
#
# NoETL provides a test script to run the agent with the weather example playbook:

# %%
# !chmod +x ../bin/test_weather_example.sh

# !../bin/test_weather_example.sh

# %% [markdown]
# ## 3. Using the REST API
#
# NoETL provides a REST API server. Here's how to use it:
#
# ### 3.1. Start the NoETL Server
#
# First, start the NoETL server:

# %%
import subprocess
import time

server_process = subprocess.Popen(["noetl", "server", "--host", "0.0.0.0", "--port", "8082", "--force"], 
                                 stdout=subprocess.PIPE, stderr=subprocess.PIPE)

time.sleep(5)
print("Server started on http://localhost:8082")
# Out:
# Server started on http://localhost:8082

# %% [markdown]
# ### 3.2. Register a Playbook in the NoETL Catalog
#
# Before executing a playbook through the NoETL API, you need to register it in the NoETL catalog:

# %%
import base64
import requests
import json

with open('../catalog/playbooks/weather_example.yaml', 'rb') as f:
    playbook_content = f.read()

playbook_base64 = base64.b64encode(playbook_content).decode('utf-8')

response = requests.post(
    "http://localhost:8082/catalog/register",
    headers={"Content-Type": "application/json"},
    json={"content_base64": playbook_base64}
)

print(f"Status code: {response.status_code}")
print(json.dumps(response.json(), indent=2))
# Out:
# Status code: 200
# {
#   "status": "success",
#   "message": "Resource 'workflows/weather/weather_loop_example' version '0.1.8' registered successfully.",
#   "resource_path": "workflows/weather/weather_loop_example",
#   "resource_version": "0.1.8",
#   "resource_type": "playbook"
# }

# %% [markdown]
# ### 3.3. Execute the Agent Synchronously
#
# Execute the agent synchronously through the API:

# %%
response = requests.post(
    "http://localhost:8082/agent/execute",
    headers={"Content-Type": "application/json"},
    json={
        "path": "workflows/weather/weather_loop_example",
        "version": "0.1.2",
        "input_payload": {
            "cities": [
                {
                    "name": "New York",
                    "lat": 40.71,
                    "lon": -74.01
                }
            ]
        },
        "sync_to_postgres": True
    }
)

print(f"Status code: {response.status_code}")
print(json.dumps(response.json(), indent=2))
# Out:
# Status code: 200
# {
#   "status": "success",
#   "message": "Agent executed successfully for playbook 'workflows/weather/weather_loop_example' version '0.1.2'.",
#   "result": {
#     "fetch_and_evaluate": {
#       "city": "New York",
#       "max_temp": 34.8,
#       "alert": true
#     },
#     "end_city_loop": {
#       "alerts": "[{'city': 'New York', 'max_temp': 34.8, 'alert': True}]"
#     },
#     "city_loop": [
#       {
#         "fetch_and_evaluate": {
#           "city": "New York",
#           "max_temp": 34.8,
#           "alert": true
#         }
#       }
#     ],
#     "start": {},
#     "aggregate_alerts": {
#       "global_alert": true,
#       "summary": {
#         "alert_cities": [
#           "New York"
#         ],
#         "count": 1
#       }
#     },
#     "log_aggregate_result": {
#       "logged": true,
#       "summary": {
#         "alert_cities": [
#           "New York"
#         ],
#         "count": 1
#       }
#     }
#   },
#   "execution_id": "6f53cfe8-94ac-4050-9baa-89c767a79290",
#   "export_path": null
# }

# %% [markdown]
# ### 3.4. Execute the Agent Asynchronously
#
# Execute the agent asynchronously through the API:

# %%
response = requests.post(
    "http://localhost:8082/agent/execute-async",
    headers={"Content-Type": "application/json"},
    json={
        "path": "workflows/weather/weather_loop_example",
        "version": "0.1.1",
        "input_payload": {
            "cities": [
                {
                    "name": "New York",
                    "lat": 40.71,
                    "lon": -74.01
                }
            ]
        },
        "sync_to_postgres": True
    }
)

print(f"Status code: {response.status_code}")
print(json.dumps(response.json(), indent=2))

event_id = response.json().get("event_id")
print(f"Event ID: {event_id}")
print(f"View events at: http://localhost:8082/events/?event_id={event_id}")
# Out:
# Status code: 200
# {
#   "status": "accepted",
#   "message": "Agent execution started for playbook 'workflows/weather/weather_loop_example' version '0.1.1'.",
#   "event_id": "evt_f27912d24eb83c35db796a58b681dd1c"
# }
# Event ID: evt_f27912d24eb83c35db796a58b681dd1c
# View events at: http://localhost:8082/events/?event_id=evt_f27912d24eb83c35db796a58b681dd1c

# %% [markdown]
# ### 3.5. NoETL CLI to Manage Playbooks
#
# Use the NoETL CLI to register and execute playbooks:
#
# #### 3.5.1. Registering a Playbook

# %%
# !noetl playbook --register ../catalog/playbooks/weather_example.yaml
# Out:
# ℹ️ [INFO]  (main:manage_playbook:298)
#      Message: Registering playbook ../catalog/playbooks/weather_example.yaml with NoETL server at http://localhost:8082/catalog/register
# ℹ️ [INFO]  (main:manage_playbook:303)
#      Message: Playbook registered successfully: {'status': 'success', 'message': "Resource 'workflows/weather/weather_loop_example' version '0.1.9' registered successfully.", 'resource_path': 'workflows/weather/weather_loop_example', 'resource_version': '0.1.9', 'resource_type': 'playbook'}
# ℹ️ [INFO]  (main:manage_playbook:304)
#      Message: Resource path: workflows/weather/weather_loop_example
# ℹ️ [INFO]  (main:manage_playbook:305)
#      Message: Resource version: 0.1.9

# %% [markdown]
# With custom host and port:

# %%
# !noetl playbook --register ../catalog/playbooks/weather_example.yaml --host localhost --port 8082
# Out:
# ℹ️ [INFO]  (main:manage_playbook:298)
#      Message: Registering playbook ../catalog/playbooks/weather_example.yaml with NoETL server at http://localhost:8082/catalog/register
# ℹ️ [INFO]  (main:manage_playbook:303)
#      Message: Playbook registered successfully: {'status': 'success', 'message': "Resource 'workflows/weather/weather_loop_example' version '0.1.10' registered successfully.", 'resource_path': 'workflows/weather/weather_loop_example', 'resource_version': '0.1.10', 'resource_type': 'playbook'}
# ℹ️ [INFO]  (main:manage_playbook:304)
#      Message: Resource path: workflows/weather/weather_loop_example
# ℹ️ [INFO]  (main:manage_playbook:305)
#      Message: Resource version: 0.1.10

# %% [markdown]
# #### 3.5.2. Executing a Playbook
#
# Execute a playbook by path with a JSON string payload:

# %%
# !noetl playbook --execute --path "workflows/weather/weather_loop_example" --payload '{"cities": [{"name": "New York", "lat": 40.71, "lon": -74.01}]}'
# Out:
# ℹ️ [INFO]  (main:manage_playbook:333)
#      Message: Parsed input payload from command line
# ℹ️ [INFO]  (main:manage_playbook:353)
#      Message: Executing playbook workflows/weather/weather_loop_example (latest version) on NoETL server at http://localhost:8082/agent/execute
# ℹ️ [INFO]  (main:manage_playbook:358)
#      Message: Playbook executed successfully
# ℹ️ [INFO]  (main:manage_playbook:361)
#      Message: Execution ID: 077d5c5f-925b-4a38-8658-ae457e7b928a
# ℹ️ [INFO]  (main:manage_playbook:362)
#      Message: Result: {
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "New York",
#                      "max_temp": 34.8,
#                      "alert": true
#                    }
#                  }
#                ],
#                "fetch_and_evaluate": {
#                  "city": "New York",
#                  "max_temp": 34.8,
#                  "alert": true
#                },
#                "start": {},
#                "end_city_loop": {
#                  "alerts": "[{'city': 'New York', 'max_temp': 34.8, 'alert': True}]"
#                },
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [
#                      "New York"
#                    ],
#                    "count": 1
#                  }
#                },
#                "aggregate_alerts": {
#                  "global_alert": true,
#                  "summary": {
#                    "alert_cities": [
#                      "New York"
#                    ],
#                    "count": 1
#                  }
#                }
#              }

# %% [markdown]
# Execute a playbook using a JSON file for input payload:

# %%
import os
import json

payload = {
    "cities": [
        {
            "name": "New York",
            "lat": 40.71,
            "lon": -74.01
        }
    ],
    "temperature_threshold": 20
}

os.makedirs("../data/input", exist_ok=True)
with open("../data/input/payload.json", "w") as f:
    json.dump(payload, f, indent=2)

# !noetl playbook --execute --path "workflows/weather/weather_loop_example" --input ../data/input/payload.json
# Out:
# ℹ️ [INFO]  (main:manage_playbook:326)
#      Message: Loaded input payload from ../data/input/payload.json
# ℹ️ [INFO]  (main:manage_playbook:353)
#      Message: Executing playbook workflows/weather/weather_loop_example (latest version) on NoETL server at http://localhost:8082/agent/execute
# ℹ️ [INFO]  (main:manage_playbook:358)
#      Message: Playbook executed successfully
# ℹ️ [INFO]  (main:manage_playbook:361)
#      Message: Execution ID: 7bc291b9-c90a-47de-bc46-c0aa8eab79fb
# ℹ️ [INFO]  (main:manage_playbook:362)
#      Message: Result: {
#                "aggregate_alerts": {
#                  "global_alert": true,
#                  "summary": {
#                    "alert_cities": [
#                      "New York"
#                    ],
#                    "count": 1
#                  }
#                },
#                "fetch_and_evaluate": {
#                  "city": "New York",
#                  "max_temp": 34.8,
#                  "alert": true
#                },
#                "start": {},
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "New York",
#                      "max_temp": 34.8,
#                      "alert": true
#                    }
#                  }
#                ],
#                "end_city_loop": {
#                  "alerts": "[{'city': 'New York', 'max_temp': 34.8, 'alert': True}]"
#                },
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [
#                      "New York"
#                    ],
#                    "count": 1
#                  }
#                }
#              }

# %% [markdown]
# Execute a playbook using the latest version (omit --version):

# %%
# !noetl playbook --execute --path "workflows/weather/weather_loop_example" --payload '{"cities": [{"name": "Chicago", "lat": 41.88, "lon": -87.63}]}'
# Out:
# ℹ️ [INFO]  (main:manage_playbook:333)
#      Message: Parsed input payload from command line
# ℹ️ [INFO]  (main:manage_playbook:353)
#      Message: Executing playbook workflows/weather/weather_loop_example (latest version) on NoETL server at http://localhost:8082/agent/execute
# ℹ️ [INFO]  (main:manage_playbook:358)
#      Message: Playbook executed successfully
# ℹ️ [INFO]  (main:manage_playbook:361)
#      Message: Execution ID: b973ac3c-9d51-4ed8-8437-e34e2a02938b
# ℹ️ [INFO]  (main:manage_playbook:362)
#      Message: Result: {
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "Chicago",
#                      "max_temp": 33.2,
#                      "alert": true
#                    }
#                  }
#                ],
#                "start": {},
#                "end_city_loop": {
#                  "alerts": "[{'city': 'Chicago', 'max_temp': 33.2, 'alert': True}]"
#                },
#                "aggregate_alerts": {
#                  "global_alert": true,
#                  "summary": {
#                    "alert_cities": [
#                      "Chicago"
#                    ],
#                    "count": 1
#                  }
#                },
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [
#                      "Chicago"
#                    ],
#                    "count": 1
#                  }
#                },
#                "fetch_and_evaluate": {
#                  "city": "Chicago",
#                  "max_temp": 33.2,
#                  "alert": true
#                }
#              }

# %% [markdown]
# Execute a playbook on a different server:

# %%
# !noetl playbook --execute --path "workflows/weather/weather_loop_example" --host localhost --port 8082 --payload '{"cities": [{"name": "London", "lat": 51.51, "lon": -0.13}]}'
# Out:
# ℹ️ [INFO]  (main:manage_playbook:333)
#      Message: Parsed input payload from command line
# ℹ️ [INFO]  (main:manage_playbook:353)
#      Message: Executing playbook workflows/weather/weather_loop_example (latest version) on NoETL server at http://localhost:8082/agent/execute
# ℹ️ [INFO]  (main:manage_playbook:358)
#      Message: Playbook executed successfully
# ℹ️ [INFO]  (main:manage_playbook:361)
#      Message: Execution ID: d0e5e87d-588c-4763-9687-81e98dbc2fc0
# ℹ️ [INFO]  (main:manage_playbook:362)
#      Message: Result: {
#                "aggregate_alerts": {
#                  "global_alert": false,
#                  "summary": {
#                    "alert_cities": [],
#                    "count": 0
#                  }
#                },
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "London",
#                      "max_temp": 25.1,
#                      "alert": false
#                    }
#                  }
#                ],
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [],
#                    "count": 0
#                  }
#                },
#                "start": {},
#                "fetch_and_evaluate": {
#                  "city": "London",
#                  "max_temp": 25.1,
#                  "alert": false
#                },
#                "end_city_loop": {
#                  "alerts": "[{'city': 'London', 'max_temp': 25.1, 'alert': False}]"
#                }
#              }

# %% [markdown]
# Execute a playbook with merge mode (merge payload with workload):

# %%
# !noetl playbook --execute --path "workflows/weather/weather_loop_example" --payload '{"cities": [{"name": "New York", "lat": 40.71, "lon": -74.01}], "temperature_threshold": 30}' --merge
# Out:
# ℹ️ [INFO]  (main:manage_playbook:333)
#      Message: Parsed input payload from command line
# ℹ️ [INFO]  (main:manage_playbook:353)
#      Message: Executing playbook workflows/weather/weather_loop_example (latest version) on NoETL server at http://localhost:8082/agent/execute
# ℹ️ [INFO]  (main:manage_playbook:358)
#      Message: Playbook executed successfully
# ℹ️ [INFO]  (main:manage_playbook:361)
#      Message: Execution ID: e94d493b-52fd-402e-ad23-4ff01f972857
# ℹ️ [INFO]  (main:manage_playbook:362)
#      Message: Result: {
#                "city_loop": [
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "London",
#                      "max_temp": 25.1,
#                      "alert": false
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "Paris",
#                      "max_temp": 25.6,
#                      "alert": false
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "Berlin",
#                      "max_temp": 30.6,
#                      "alert": true
#                    }
#                  },
#                  {
#                    "fetch_and_evaluate": {
#                      "city": "New York",
#                      "max_temp": 34.8,
#                      "alert": true
#                    }
#                  }
#                ],
#                "start": {},
#                "fetch_and_evaluate": {
#                  "city": "Paris",
#                  "max_temp": 25.6,
#                  "alert": false
#                },
#                "aggregate_alerts": {
#                  "global_alert": true,
#                  "summary": {
#                    "alert_cities": [
#                      "Berlin",
#                      "New York"
#                    ],
#                    "count": 2
#                  }
#                },
#                "end_city_loop": {
#                  "alerts": "[{'city': 'London', 'max_temp': 25.1, 'alert': False}, {'city': 'Paris', 'max_temp': 25.6, 'alert': False}, {'city': 'Berlin', 'max_temp': 30.6, 'alert': True}, {'city': 'New York', 'max_temp': 34.8, 'alert': True}]"
#                },
#                "log_aggregate_result": {
#                  "logged": true,
#                  "summary": {
#                    "alert_cities": [
#                      "Berlin",
#                      "New York"
#                    ],
#                    "count": 2
#                  }
#                }
#              }

# %% [markdown]
# ## 4. Using Docker
#
# You can run NoETL using Docker:
#
# ### 4.1. Build and Start the Docker Containers

# %%
# !cd .. && make build
# Out:
# docker compose -f docker-compose.yaml -p noetl build
# [+] Building 0/0
#  ⠋ Service jupyter  Building                                               0.1s
#  ⠋ Service db       Building                                               0.1s
# [+] Building 0.0s (1/1)                                    docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
# [+] Building 0/2
#  ⠙ Service jupyter  Building                                               0.2s
#  ⠙ Service db       Building                                               0.2s
# [+] Building 0/2
#  ⠹ Service jupyter  Building                                               0.3s
#  ⠹ Service db       Building                                               0.3s
# [+] Building 0.2s (2/4)                                    docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
#  => => transferring dockerfile: 515B                                       0.0s
#  => [db internal] load build definition from Dockerfile                    0.0s
#  => => transferring dockerfile: 792B                                       0.0s
#  => [jupyter internal] load metadata for docker.io/jupyter/datascience-no  0.2s
#  => [db internal] load metadata for docker.io/library/postgres:17.4        0.2s
# [+] Building 0/2
#  ⠸ Service jupyter  Building                                               0.4s
#  ⠸ Service db       Building                                               0.4s
# [+] Building 0.3s (2/4)                                    docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
#  => => transferring dockerfile: 515B                                       0.0s
#  => [db internal] load build definition from Dockerfile                    0.0s
#  => => transferring dockerfile: 792B                                       0.0s
#  => [jupyter internal] load metadata for docker.io/jupyter/datascience-no  0.3s
#  => [db internal] load metadata for docker.io/library/postgres:17.4        0.3s
# [+] Building 0/2
#  ⠼ Service jupyter  Building                                               0.5s
#  ⠼ Service db       Building                                               0.5s
# [+] Building 0/2
#  ⠴ Service jupyter  Building                                               0.6s
#  ⠴ Service db       Building                                               0.6s
# [+] Building 0.5s (2/4)                                    docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
#  => => transferring dockerfile: 515B                                       0.0s
#  => [db internal] load build definition from Dockerfile                    0.0s
#  => => transferring dockerfile: 792B                                       0.0s
#  => [jupyter internal] load metadata for docker.io/jupyter/datascience-no  0.5s
#  => [db internal] load metadata for docker.io/library/postgres:17.4        0.5s
# [+] Building 0/2
#  ⠦ Service jupyter  Building                                               0.7s
#  ⠦ Service db       Building                                               0.7s
# [+] Building 0.6s (2/4)                                    docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
#  => => transferring dockerfile: 515B                                       0.0s
#  => [db internal] load build definition from Dockerfile                    0.0s
#  => => transferring dockerfile: 792B                                       0.0s
#  => [jupyter internal] load metadata for docker.io/jupyter/datascience-no  0.6s
#  => [db internal] load metadata for docker.io/library/postgres:17.4        0.6s
# [+] Building 0/2
#  ⠧ Service jupyter  Building                                               0.8s
#  ⠧ Service db       Building                                               0.8s
# [+] Building 0/2
#  ⠇ Service jupyter  Building                                               0.9s
#  ⠇ Service db       Building                                               0.9s
# [+] Building 0.8s (2/4)                                    docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
#  => => transferring dockerfile: 515B                                       0.0s
#  => [db internal] load build definition from Dockerfile                    0.0s
#  => => transferring dockerfile: 792B                                       0.0s
#  => [jupyter internal] load metadata for docker.io/jupyter/datascience-no  0.8s
#  => [db internal] load metadata for docker.io/library/postgres:17.4        0.8s
# [+] Building 0/2
#  ⠏ Service jupyter  Building                                               1.0s
#  ⠏ Service db       Building                                               1.0s
# [+] Building 0.9s (3/4)                                    docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
#  => => transferring dockerfile: 515B                                       0.0s
#  => [db internal] load build definition from Dockerfile                    0.0s
#  => => transferring dockerfile: 792B                                       0.0s
#  => [jupyter internal] load metadata for docker.io/jupyter/datascience-no  0.9s
#  => [db internal] load metadata for docker.io/library/postgres:17.4        0.9s
# [+] Building 0/2
#  ⠋ Service jupyter  Building                                               1.1s
#  ⠋ Service db       Building                                               1.1s
# [+] Building 1.0s (16/18)                                  docker:desktop-linux
#  => => resolve docker.io/jupyter/datascience-notebook:latest@sha256:476c6  0.0s
#  => [db 1/6] FROM docker.io/library/postgres:17.4@sha256:304ab81351875422  0.0s
#  => => resolve docker.io/library/postgres:17.4@sha256:304ab813518754228f9  0.0s
#  => [db internal] load build context                                       0.0s
#  => => transferring context: 36.78kB                                       0.0s
#  => CACHED [jupyter 2/3] RUN pip install --no-cache-dir     duckdb>=1.3.0  0.0s
#  => CACHED [jupyter 3/3] RUN jupyter server extension enable jupysql       0.0s
#  => [jupyter] exporting to image                                           0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:86a2a37f6f51e8fe2fd654a1a35b05a09a8d2955  0.0s
#  => => exporting config sha256:55a86e19c00296a29ddf5370deec4fa2ae214356dd  0.0s
#  => => exporting attestation manifest sha256:25d30d7c25d17f7bfe3c049472cb  0.0s
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.0s
#  => => exporting layers                                                    0.0s
# [+] Building 0/2
#  ⠙ Service jupyter  Building                                               1.2s
#  ⠙ Service db       Building                                               1.2s
# [+] Building 1.1s (19/20)                                  docker:desktop-linux
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:86a2a37f6f51e8fe2fd654a1a35b05a09a8d2955  0.0s
#  => => exporting config sha256:55a86e19c00296a29ddf5370deec4fa2ae214356dd  0.0s
#  => => exporting attestation manifest sha256:25d30d7c25d17f7bfe3c049472cb  0.0s
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
# [+] Building 2/2
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠋ Service api      Building                                               0.0s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠙ Service api      Building                                               0.1s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠹ Service api      Building                                               0.2s
# [+] Building 1.4s (21/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.1s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           0.1s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠸ Service api      Building                                               0.3s
# [+] Building 1.5s (21/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.3s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           0.3s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠼ Service api      Building                                               0.4s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠴ Service api      Building                                               0.5s
# [+] Building 1.7s (21/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.4s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           0.4s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠦ Service api      Building                                               0.6s
# [+] Building 1.8s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           0.6s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠧ Service api      Building                                               0.7s
# [+] Building 1.9s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           0.7s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠇ Service api      Building                                               0.8s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠏ Service api      Building                                               0.9s
# [+] Building 2.1s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           0.9s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠋ Service api      Building                                               1.0s
# [+] Building 2.2s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           1.0s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠙ Service api      Building                                               1.1s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠹ Service api      Building                                               1.2s
# [+] Building 2.4s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           1.2s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠸ Service api      Building                                               1.3s
# [+] Building 2.5s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           1.3s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠼ Service api      Building                                               1.4s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠴ Service api      Building                                               1.5s
# [+] Building 2.7s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           1.5s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠦ Service api      Building                                               1.6s
# [+] Building 2.8s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           1.6s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠧ Service api      Building                                               1.7s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠇ Service api      Building                                               1.8s
# [+] Building 3.0s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           1.8s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠏ Service api      Building                                               1.9s
# [+] Building 3.1s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           1.9s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠋ Service api      Building                                               2.0s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠙ Service api      Building                                               2.1s
# [+] Building 3.3s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           2.1s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠹ Service api      Building                                               2.2s
# [+] Building 3.4s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           2.2s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠸ Service api      Building                                               2.3s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠼ Service api      Building                                               2.4s
# [+] Building 3.6s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           2.4s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠴ Service api      Building                                               2.5s
# [+] Building 3.7s (22/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           2.5s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠦ Service api      Building                                               2.6s
# [+] Building 3.8s (23/23)                                  docker:desktop-linux
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
# ...
#  => [api stage-0 3/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /b  0.1s
#  => [api stage-0 4/8] RUN ln -snf /usr/share/zoneinfo/America/Chicago /et  0.1s
#  => [api stage-0 5/8] WORKDIR /opt/noetl                                   0.0s
#  => [api stage-0 6/8] COPY pyproject.toml ./                               0.0s
#  => [api stage-0 7/8] COPY noetl ./noetl                                   0.0s
#  => [api stage-0 8/8] RUN pip install --upgrade pip  && pip install .  &  50.3s
#  => [api] exporting to image                                              40.5s
#  => => exporting layers                                                   31.8s
#  => => exporting manifest sha256:45f459299f0ff6485520eda2a11018944b7974a9  0.0s
#  => => exporting config sha256:404b3f3e4af4399e583474144766078228af82802e  0.0s
#  => => exporting attestation manifest sha256:f79fcb950e306dc353cab2300ccf  0.0s
#  => => exporting manifest list sha256:998638ada184d0b9fdd962d2b164a614dcd  0.0s
#  => => naming to docker.io/library/noetl-api:latest                        0.0s
#  => => unpacking to docker.io/library/noetl-api:latest                     8.7s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠙ Service api      Building                                              95.1s
# [+] Building 96.4s (34/35)                                 docker:desktop-linux
#  => => transferring context: 322.64kB                                      0.0s
#  => [api] FROM ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  1.3s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  0.0s
#  => => sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1 17.09MB / 17.09MB  1.2s
#  => => sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1d 98B / 98B  0.6s
#  => => extracting sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1ed1372c  0.1s
#  => => extracting sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1  0.0s
#  => CACHED [api stage-0 2/8] RUN apt-get update  && apt-get --no-install-  0.0s
#  => [api stage-0 3/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /b  0.1s
#  => [api stage-0 4/8] RUN ln -snf /usr/share/zoneinfo/America/Chicago /et  0.1s
#  => [api stage-0 5/8] WORKDIR /opt/noetl                                   0.0s
#  => [api stage-0 6/8] COPY pyproject.toml ./                               0.0s
#  => [api stage-0 7/8] COPY noetl ./noetl                                   0.0s
#  => [api stage-0 8/8] RUN pip install --upgrade pip  && pip install .  &  50.3s
#  => [api] exporting to image                                              40.6s
#  => => exporting layers                                                   31.8s
#  => => exporting manifest sha256:45f459299f0ff6485520eda2a11018944b7974a9  0.0s
#  => => exporting config sha256:404b3f3e4af4399e583474144766078228af82802e  0.0s
#  => => exporting attestation manifest sha256:f79fcb950e306dc353cab2300ccf  0.0s
#  => => exporting manifest list sha256:998638ada184d0b9fdd962d2b164a614dcd  0.0s
#  => => naming to docker.io/library/noetl-api:latest                        0.0s
# [+] Building 2/3
#  => => unpacking to docker.io/library/noetl-api:latest                     8.8s
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠹ Service api      Building                                              95.2s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠸ Service api      Building                                              95.3s
# [+] Building 96.5s (34/35)                                 docker:desktop-linux
#  => => transferring context: 322.64kB                                      0.0s
#  => [api] FROM ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  1.3s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  0.0s
#  => => sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1 17.09MB / 17.09MB  1.2s
#  => => sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1d 98B / 98B  0.6s
#  => => extracting sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1ed1372c  0.1s
#  => => extracting sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1  0.0s
#  => CACHED [api stage-0 2/8] RUN apt-get update  && apt-get --no-install-  0.0s
#  => [api stage-0 3/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /b  0.1s
#  => [api stage-0 4/8] RUN ln -snf /usr/share/zoneinfo/America/Chicago /et  0.1s
#  => [api stage-0 5/8] WORKDIR /opt/noetl                                   0.0s
#  => [api stage-0 6/8] COPY pyproject.toml ./                               0.0s
#  => [api stage-0 7/8] COPY noetl ./noetl                                   0.0s
#  => [api stage-0 8/8] RUN pip install --upgrade pip  && pip install .  &  50.3s
#  => [api] exporting to image                                              40.8s
#  => => exporting layers                                                   31.8s
#  => => exporting manifest sha256:45f459299f0ff6485520eda2a11018944b7974a9  0.0s
#  => => exporting config sha256:404b3f3e4af4399e583474144766078228af82802e  0.0s
#  => => exporting attestation manifest sha256:f79fcb950e306dc353cab2300ccf  0.0s
#  => => exporting manifest list sha256:998638ada184d0b9fdd962d2b164a614dcd  0.0s
#  => => naming to docker.io/library/noetl-api:latest                        0.0s
#  => => unpacking to docker.io/library/noetl-api:latest                     9.0s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠼ Service api      Building                                              95.4s
# [+] Building 96.6s (34/35)                                 docker:desktop-linux
#  => => transferring context: 322.64kB                                      0.0s
#  => [api] FROM ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  1.3s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  0.0s
#  => => sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1 17.09MB / 17.09MB  1.2s
#  => => sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1d 98B / 98B  0.6s
#  => => extracting sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1ed1372c  0.1s
#  => => extracting sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1  0.0s
#  => CACHED [api stage-0 2/8] RUN apt-get update  && apt-get --no-install-  0.0s
#  => [api stage-0 3/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /b  0.1s
#  => [api stage-0 4/8] RUN ln -snf /usr/share/zoneinfo/America/Chicago /et  0.1s
#  => [api stage-0 5/8] WORKDIR /opt/noetl                                   0.0s
#  => [api stage-0 6/8] COPY pyproject.toml ./                               0.0s
#  => [api stage-0 7/8] COPY noetl ./noetl                                   0.0s
#  => [api stage-0 8/8] RUN pip install --upgrade pip  && pip install .  &  50.3s
#  => [api] exporting to image                                              40.9s
#  => => exporting layers                                                   31.8s
#  => => exporting manifest sha256:45f459299f0ff6485520eda2a11018944b7974a9  0.0s
#  => => exporting config sha256:404b3f3e4af4399e583474144766078228af82802e  0.0s
#  => => exporting attestation manifest sha256:f79fcb950e306dc353cab2300ccf  0.0s
#  => => exporting manifest list sha256:998638ada184d0b9fdd962d2b164a614dcd  0.0s
#  => => naming to docker.io/library/noetl-api:latest                        0.0s
#  => => unpacking to docker.io/library/noetl-api:latest                     9.1s
# [+] Building 2/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ⠴ Service api      Building                                              95.5s
# [+] Building 96.7s (36/36)                                 docker:desktop-linux
#  => [api] FROM ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  1.3s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  0.0s
#  => => sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1 17.09MB / 17.09MB  1.2s
#  => => sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1d 98B / 98B  0.6s
#  => => extracting sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1ed1372c  0.1s
#  => => extracting sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1  0.0s
#  => CACHED [api stage-0 2/8] RUN apt-get update  && apt-get --no-install-  0.0s
#  => [api stage-0 3/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /b  0.1s
#  => [api stage-0 4/8] RUN ln -snf /usr/share/zoneinfo/America/Chicago /et  0.1s
#  => [api stage-0 5/8] WORKDIR /opt/noetl                                   0.0s
#  => [api stage-0 6/8] COPY pyproject.toml ./                               0.0s
#  => [api stage-0 7/8] COPY noetl ./noetl                                   0.0s
#  => [api stage-0 8/8] RUN pip install --upgrade pip  && pip install .  &  50.3s
#  => [api] exporting to image                                              40.9s
#  => => exporting layers                                                   31.8s
#  => => exporting manifest sha256:45f459299f0ff6485520eda2a11018944b7974a9  0.0s
#  => => exporting config sha256:404b3f3e4af4399e583474144766078228af82802e  0.0s
#  => => exporting attestation manifest sha256:f79fcb950e306dc353cab2300ccf  0.0s
#  => => exporting manifest list sha256:998638ada184d0b9fdd962d2b164a614dcd  0.0s
#  => => naming to docker.io/library/noetl-api:latest                        0.0s
#  => => unpacking to docker.io/library/noetl-api:latest                     9.1s
#  => [api] resolving provenance for metadata file                           0.0s
# [+] Building 96.7s (36/36) FINISHED                        docker:desktop-linux
#  => [jupyter internal] load build definition from Dockerfile               0.0s
#  => => transferring dockerfile: 515B                                       0.0s
#  => [db internal] load build definition from Dockerfile                    0.0s
#  => => transferring dockerfile: 792B                                       0.0s
#  => [jupyter internal] load metadata for docker.io/jupyter/datascience-no  0.9s
#  => [db internal] load metadata for docker.io/library/postgres:17.4        0.9s
#  => [jupyter internal] load .dockerignore                                  0.0s
#  => => transferring context: 2B                                            0.0s
#  => [db internal] load .dockerignore                                       0.0s
#  => => transferring context: 2B                                            0.0s
#  => [jupyter 1/3] FROM docker.io/jupyter/datascience-notebook:latest@sha2  0.0s
#  => => resolve docker.io/jupyter/datascience-notebook:latest@sha256:476c6  0.0s
#  => [db 1/6] FROM docker.io/library/postgres:17.4@sha256:304ab81351875422  0.0s
#  => => resolve docker.io/library/postgres:17.4@sha256:304ab813518754228f9  0.0s
#  => [db internal] load build context                                       0.0s
#  => => transferring context: 36.78kB                                       0.0s
#  => CACHED [jupyter 2/3] RUN pip install --no-cache-dir     duckdb>=1.3.0  0.0s
#  => CACHED [jupyter 3/3] RUN jupyter server extension enable jupysql       0.0s
#  => [jupyter] exporting to image                                           0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:86a2a37f6f51e8fe2fd654a1a35b05a09a8d2955  0.0s
#  => => exporting config sha256:55a86e19c00296a29ddf5370deec4fa2ae214356dd  0.0s
#  => => exporting attestation manifest sha256:25d30d7c25d17f7bfe3c049472cb  0.0s
#  => => exporting manifest list sha256:d44f6e29be98f75a64b0536585ea25f807d  0.0s
#  => => naming to docker.io/library/noetl-jupyter:latest                    0.0s
#  => => unpacking to docker.io/library/noetl-jupyter:latest                 0.0s
#  => CACHED [db 2/6] RUN apt-get update &&     DEBIAN_FRONTEND=noninteract  0.0s
#  => CACHED [db 3/6] RUN ln -snf /usr/share/zoneinfo/America/Chicago /etc/  0.0s
#  => CACHED [db 4/6] COPY ../database/postgres/postgresql.conf /etc/postgr  0.0s
#  => CACHED [db 5/6] COPY ../database/postgres/init_database.sh /docker-en  0.0s
#  => [db 6/6] COPY ../database/postgres/schema_ddl.sql /schema_ddl.sql      0.0s
#  => [db] exporting to image                                                0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:54e39619e0b0d3f5fd7dd0affdf1b27c1b0c2724  0.0s
#  => => exporting config sha256:2a046e6d668194acef7a0d8690b0e9566aec2982b0  0.0s
#  => => exporting attestation manifest sha256:69ebd83ff66d0995c3135731e0e3  0.0s
#  => => exporting manifest list sha256:d8e3f00892f3d2b325e929673782f2976f7  0.0s
#  => => naming to docker.io/library/noetl-db:latest                         0.0s
#  => => unpacking to docker.io/library/noetl-db:latest                      0.0s
#  => [jupyter] resolving provenance for metadata file                       0.0s
#  => [db] resolving provenance for metadata file                            0.0s
#  => [api internal] load build definition from Dockerfile                   0.0s
#  => => transferring dockerfile: 997B                                       0.0s
#  => [api internal] load metadata for docker.io/library/python:3.12-slim    0.6s
#  => [api internal] load metadata for ghcr.io/astral-sh/uv:latest           2.6s
#  => [api internal] load .dockerignore                                      0.0s
#  => => transferring context: 2B                                            0.0s
#  => [api stage-0 1/8] FROM docker.io/library/python:3.12-slim@sha256:e555  0.0s
#  => => resolve docker.io/library/python:3.12-slim@sha256:e55523f127124e5e  0.0s
#  => [api internal] load build context                                      0.0s
#  => => transferring context: 322.64kB                                      0.0s
#  => [api] FROM ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  1.3s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:9653efd4380d5a0e5511e33  0.0s
#  => => sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1 17.09MB / 17.09MB  1.2s
#  => => sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1d 98B / 98B  0.6s
#  => => extracting sha256:a4992bb42fe06cab8e32b16e9c234d61d6b12b6c1ed1372c  0.1s
#  => => extracting sha256:3126006e76f962bf728602e62931706189e2b7dab58d24b1  0.0s
#  => CACHED [api stage-0 2/8] RUN apt-get update  && apt-get --no-install-  0.0s
#  => [api stage-0 3/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx /b  0.1s
#  => [api stage-0 4/8] RUN ln -snf /usr/share/zoneinfo/America/Chicago /et  0.1s
#  => [api stage-0 5/8] WORKDIR /opt/noetl                                   0.0s
#  => [api stage-0 6/8] COPY pyproject.toml ./                               0.0s
#  => [api stage-0 7/8] COPY noetl ./noetl                                   0.0s
#  => [api stage-0 8/8] RUN pip install --upgrade pip  && pip install .  &  50.3s
#  => [api] exporting to image                                              40.9s
#  => => exporting layers                                                   31.8s
#  => => exporting manifest sha256:45f459299f0ff6485520eda2a11018944b7974a9  0.0s
#  => => exporting config sha256:404b3f3e4af4399e583474144766078228af82802e  0.0s
#  => => exporting attestation manifest sha256:f79fcb950e306dc353cab2300ccf  0.0s
#  => => exporting manifest list sha256:998638ada184d0b9fdd962d2b164a614dcd  0.0s
#  => => naming to docker.io/library/noetl-api:latest                        0.0s
#  => => unpacking to docker.io/library/noetl-api:latest                     9.1s
#  => [api] resolving provenance for metadata file                           0.0s
# [+] Building 3/3
#  ✔ Service jupyter  Built                                                  1.2s
#  ✔ Service db       Built                                                  1.3s
#  ✔ Service api      Built                                                 95.6s

# %%
# !cd .. && make up
# Out:
# docker compose -f docker-compose.yaml -p noetl up -d
# [+] Running 0/0
#  ⠋ Container noetl-jupyter  Recreate                                       0.0s
# [+] Running 0/1
#  ⠙ Container noetl-jupyter  Recreate                                       0.1s
#  ⠋ Container noetl-api      Stopping                                       0.1s
# [+] Running 0/2
#  ⠹ Container noetl-jupyter  Recreate                                       0.3s
#  ⠙ Container noetl-api      Stopping                                       0.2s
# [+] Running 0/2
#  ⠸ Container noetl-jupyter  Recreate                                       0.3s
#  ⠹ Container noetl-api      Stopping                                       0.3s
# [+] Running 0/2
#  ⠼ Container noetl-jupyter  Recreate                                       0.4s
#  ⠸ Container noetl-api      Stopping                                       0.4s
# [+] Running 0/2
#  ⠴ Container noetl-jupyter  Recreate                                       0.5s
#  ⠼ Container noetl-api      Stopping                                       0.5s
# [+] Running 0/2
#  ⠦ Container noetl-jupyter  Recreate                                       0.6s
#  ⠴ Container noetl-api      Stopping                                       0.6s
# [+] Running 0/2
#  ⠧ Container noetl-jupyter  Recreate                                       0.7s
#  ⠦ Container noetl-api      Stopping                                       0.7s
# [+] Running 0/2
#  ⠇ Container noetl-jupyter  Recreate                                       0.8s
#  ⠧ Container noetl-api      Stopping                                       0.8s
# [+] Running 1/2
#  ⠏ Container noetl-jupyter   Recreate                                      0.9s
#  ✔ Container noetl-api       Stopped                                       0.8s
#  ⠋ Container noetl-database  Recreate                                      0.0s
# [+] Running 1/3
#  ⠋ Container noetl-jupyter   Recreate                                      1.0s
#  ✔ Container noetl-api       Stopped                                       0.8s
#  ⠙ Container noetl-database  Recreate                                      0.1s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ✔ Container noetl-api       Stopped                                       0.8s
#  ⠹ Container noetl-database  Recreate                                      0.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ✔ Container noetl-api       Stopped                                       0.8s
#  ⠸ Container noetl-database  Recreate                                      0.3s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ✔ Container noetl-api       Stopped                                       0.8s
#  ⠼ Container noetl-database  Recreate                                      0.4s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ✔ Container noetl-api       Stopped                                       0.8s
#  ⠴ Container noetl-database  Recreate                                      0.5s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ✔ Container noetl-api       Stopped                                       0.8s
#  ⠦ Container noetl-database  Recreate                                      0.6s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠇ Container noetl-api       Recreate                                      1.6s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠏ Container noetl-api       Recreate                                      1.7s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠋ Container noetl-api       Recreate                                      1.8s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠙ Container noetl-api       Recreate                                      1.9s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠹ Container noetl-api       Recreate                                      2.0s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠸ Container noetl-api       Recreate                                      2.1s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠼ Container noetl-api       Recreate                                      2.2s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠴ Container noetl-api       Recreate                                      2.3s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠦ Container noetl-api       Recreate                                      2.4s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠧ Container noetl-api       Recreate                                      2.5s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠇ Container noetl-api       Recreate                                      2.6s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠏ Container noetl-api       Recreate                                      2.7s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠋ Container noetl-api       Recreate                                      2.8s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠙ Container noetl-api       Recreate                                      2.9s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠹ Container noetl-api       Recreate                                      3.0s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠸ Container noetl-api       Recreate                                      3.1s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠼ Container noetl-api       Recreate                                      3.2s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠴ Container noetl-api       Recreate                                      3.3s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠦ Container noetl-api       Recreate                                      3.4s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠧ Container noetl-api       Recreate                                      3.5s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠇ Container noetl-api       Recreate                                      3.6s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠏ Container noetl-api       Recreate                                      3.7s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠋ Container noetl-api       Recreate                                      3.8s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠙ Container noetl-api       Recreate                                      3.9s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠹ Container noetl-api       Recreate                                      4.0s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠸ Container noetl-api       Recreate                                      4.1s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Recreated                                     1.1s
#  ⠼ Container noetl-api       Recreate                                      4.2s
#  ✔ Container noetl-database  Recreated                                     0.7s
# [+] Running 1/3
#  ⠙ Container noetl-jupyter   Starting                                      4.3s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠧ Container noetl-database  Starting                                      3.4s
# [+] Running 1/3
#  ⠹ Container noetl-jupyter   Starting                                      4.4s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠇ Container noetl-database  Starting                                      3.5s
# [+] Running 1/3
#  ⠸ Container noetl-jupyter   Starting                                      4.5s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠏ Container noetl-database  Starting                                      3.6s
# [+] Running 1/3
#  ⠼ Container noetl-jupyter   Starting                                      4.6s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠋ Container noetl-database  Waiting                                       3.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠙ Container noetl-database  Waiting                                       3.8s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠹ Container noetl-database  Waiting                                       3.9s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠸ Container noetl-database  Waiting                                       4.0s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠼ Container noetl-database  Waiting                                       4.1s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠴ Container noetl-database  Waiting                                       4.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠦ Container noetl-database  Waiting                                       4.3s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠧ Container noetl-database  Waiting                                       4.4s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠇ Container noetl-database  Waiting                                       4.5s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠏ Container noetl-database  Waiting                                       4.6s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠋ Container noetl-database  Waiting                                       4.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠙ Container noetl-database  Waiting                                       4.8s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠹ Container noetl-database  Waiting                                       4.9s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠸ Container noetl-database  Waiting                                       5.0s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠼ Container noetl-database  Waiting                                       5.1s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠴ Container noetl-database  Waiting                                       5.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠦ Container noetl-database  Waiting                                       5.3s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠧ Container noetl-database  Waiting                                       5.4s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠇ Container noetl-database  Waiting                                       5.5s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠏ Container noetl-database  Waiting                                       5.6s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠋ Container noetl-database  Waiting                                       5.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠙ Container noetl-database  Waiting                                       5.8s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠹ Container noetl-database  Waiting                                       5.9s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠸ Container noetl-database  Waiting                                       6.0s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠼ Container noetl-database  Waiting                                       6.1s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠴ Container noetl-database  Waiting                                       6.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠦ Container noetl-database  Waiting                                       6.3s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠧ Container noetl-database  Waiting                                       6.4s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠇ Container noetl-database  Waiting                                       6.5s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠏ Container noetl-database  Waiting                                       6.6s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠋ Container noetl-database  Waiting                                       6.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠙ Container noetl-database  Waiting                                       6.8s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠹ Container noetl-database  Waiting                                       6.9s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠸ Container noetl-database  Waiting                                       7.0s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠼ Container noetl-database  Waiting                                       7.1s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠴ Container noetl-database  Waiting                                       7.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠦ Container noetl-database  Waiting                                       7.3s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠧ Container noetl-database  Waiting                                       7.4s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠇ Container noetl-database  Waiting                                       7.5s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠏ Container noetl-database  Waiting                                       7.6s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠋ Container noetl-database  Waiting                                       7.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠙ Container noetl-database  Waiting                                       7.8s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠹ Container noetl-database  Waiting                                       7.9s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠸ Container noetl-database  Waiting                                       8.0s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠼ Container noetl-database  Waiting                                       8.1s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠴ Container noetl-database  Waiting                                       8.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠦ Container noetl-database  Waiting                                       8.3s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠧ Container noetl-database  Waiting                                       8.4s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠇ Container noetl-database  Waiting                                       8.5s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠏ Container noetl-database  Waiting                                       8.6s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠋ Container noetl-database  Waiting                                       8.7s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠙ Container noetl-database  Waiting                                       8.8s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠹ Container noetl-database  Waiting                                       8.9s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠸ Container noetl-database  Waiting                                       9.0s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Recreated                                     4.2s
#  ⠼ Container noetl-database  Waiting                                       9.1s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ⠴ Container noetl-api       Starting                                     10.1s
#  ✔ Container noetl-database  Healthy                                       9.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ⠦ Container noetl-api       Starting                                     10.2s
#  ✔ Container noetl-database  Healthy                                       9.2s
# [+] Running 2/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ⠧ Container noetl-api       Starting                                     10.3s
#  ✔ Container noetl-database  Healthy                                       9.2s
# [+] Running 3/3
#  ✔ Container noetl-jupyter   Started                                       4.7s
#  ✔ Container noetl-api       Started                                      10.3s
#  ✔ Container noetl-database  Healthy                                       9.2s

# %% [markdown]
# ### 4.2. Use the API as Described in Section 3
#
# By default, the API will be available at `http://localhost:8082`.

# %% [markdown]
# ## Cleanup
#
# If you started the NoETL server in this notebook, make sure to stop it:

# %%
try:
    server_process.terminate()
    print("Server stopped")
except NameError:
    print("No server process to stop")
# Out:
# Server stopped

# %% [markdown]
# If you started Docker containers, you can stop them:

# %%
# !cd .. && make down
# Out:
# docker compose -f docker-compose.yaml -p noetl down
# [+] Running 0/0
#  ⠋ Container noetl-api      Stopping                                       0.0s
#  ⠋ Container noetl-jupyter  Stopping                                       0.0s
# [+] Running 0/2
#  ⠙ Container noetl-api      Stopping                                       0.1s
#  ⠙ Container noetl-jupyter  Stopping                                       0.1s
# [+] Running 0/2
#  ⠹ Container noetl-api      Stopping                                       0.2s
#  ⠹ Container noetl-jupyter  Stopping                                       0.2s
# [+] Running 0/2
#  ⠸ Container noetl-api      Stopping                                       0.3s
#  ⠸ Container noetl-jupyter  Stopping                                       0.3s
# [+] Running 0/2
#  ⠼ Container noetl-api      Removing                                       0.4s
#  ⠼ Container noetl-jupyter  Removing                                       0.4s
# [+] Running 0/2
#  ⠴ Container noetl-api      Removing                                       0.5s
#  ⠴ Container noetl-jupyter  Removing                                       0.5s
# [+] Running 0/2
#  ⠦ Container noetl-api      Removing                                       0.6s
#  ⠦ Container noetl-jupyter  Removing                                       0.6s
# [+] Running 0/2
#  ⠧ Container noetl-api      Removing                                       0.7s
#  ⠧ Container noetl-jupyter  Removing                                       0.7s
# [+] Running 0/2
#  ⠇ Container noetl-api      Removing                                       0.8s
#  ⠇ Container noetl-jupyter  Removing                                       0.8s
# [+] Running 2/2
#  ✔ Container noetl-api       Removed                                       0.9s
#  ✔ Container noetl-jupyter   Removed                                       0.9s
#  ⠋ Container noetl-database  Stopping                                      0.1s
# [+] Running 2/3
#  ✔ Container noetl-api       Removed                                       0.9s
#  ✔ Container noetl-jupyter   Removed                                       0.9s
#  ⠙ Container noetl-database  Stopping                                      0.2s
# [+] Running 3/3
#  ✔ Container noetl-api       Removed                                       0.9s
#  ✔ Container noetl-jupyter   Removed                                       0.9s
#  ✔ Container noetl-database  Removed                                       0.2s
#  ⠋ Network noetl-network     Removing                                      0.0s
# [+] Running 4/4
#  ✔ Container noetl-api       Removed                                       0.9s
#  ✔ Container noetl-jupyter   Removed                                       0.9s
#  ✔ Container noetl-database  Removed                                       0.2s
#  ✔ Network noetl-network     Removed                                       0.1s
